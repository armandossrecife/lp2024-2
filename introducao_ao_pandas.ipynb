# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/lp2024-2/blob/main/introducao_ao_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# É uma biblioteca (open-source) Python usada para manipular (extrair, analisar, limpar, explorar, sumarizar, ...) conjuntos de dados.
#
# https://pandas.pydata.org/

# %% [markdown]
# *Estrutura de dados*: Pandas oferece duas estruturas de dados principais: **Series** e **DataFrame**. Uma Series é um array unidimensional que pode conter qualquer tipo de dados, enquanto um DataFrame é uma estrutura de dados tabular bidimensional que consiste em linhas e colunas.
#
# *Manipulação de dados*: Pandas oferece muitas ferramentas para manipular dados, incluindo filtragem, seleção, ordenação, agregação e transformação. Isso permite que você trabalhe facilmente com dados para realizar tarefas comuns de análise de dados.
#
# *Limpeza de dados*: Pandas oferece uma ampla gama de ferramentas para limpeza de dados, incluindo preenchimento de valores nulos, remoção de duplicatas e correção de erros de dados.
#
# *Visualização de dados*: Pandas integra-se bem com a biblioteca de visualização de dados do Python, Matplotlib, permitindo que você crie visualizações poderosas diretamente de seus dados.
#
# *Importação e exportação de dados*: Pandas pode ler e gravar dados em vários formatos, incluindo CSV, Excel, SQL, JSON e muito mais.
#
# Integração com outras bibliotecas Python: Pandas é uma biblioteca muito popular e é frequentemente usada em conjunto com outras bibliotecas Python, como NumPy, Scikit-Learn e TensorFlow, entre outras.

# %% [markdown]
# Bibliotecas mais importantes

# %%
# importa as principais biblioteca
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Exemplos

# %% [markdown]
# ## Dados abertos do TSE (Tribunal Superior Eleitoral 2024)
#
# https://dadosabertos.tse.jus.br/dataset/resultados-2024-boletim-de-urna

# %% [markdown]
# ### Urnas do PI

# %%
# !unzip bweb_1t_PI_091020241636.zip
# Out:
# Archive:  bweb_1t_PI_091020241636.zip
#   inflating: bweb_1t_PI_091020241636.csv
#   inflating: _leiame-boletimurnaweb.pdf

# %%
# !ls -lh
# Out:
# total 252M
# -rw-rw-r-- 1 root root 218M Oct  9 22:08 bweb_1t_PI_091020241636.csv
# -rw-r--r-- 1 root root  34M Oct 29 15:18 bweb_1t_PI_091020241636.zip
# -rw-r--r-- 1 root root 203K Oct 17 17:11 _leiame-boletimurnaweb.pdf
# drwxr-xr-x 1 root root 4.0K Oct 25 13:20 sample_data

# %%
# !wc -l bweb_1t_PI_091020241636.csv
# Out:
# 504686 bweb_1t_PI_091020241636.csv

# %%
df_boletim_urnas_pi = pd.read_csv('bweb_1t_PI_091020241636.csv', sep=';', encoding='latin1')

# %%
df_boletim_urnas_pi.head(10)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 1  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 2  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 3  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 4  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 5  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 6  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 7  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 8  09/10/2024   16:36:29         2024                0  Eleição Ordinária
# 9  09/10/2024   16:36:29         2024                0  Eleição Ordinária
#
#    CD_PLEITO            DT_PLEITO  NR_TURNO  CD_ELEICAO  \
# 0        452  2024-10-06 00:00:00         1         619
# 1        452  2024-10-06 00:00:00         1         619
# 2        452  2024-10-06 00:00:00         1         619
# 3        452  2024-10-06 00:00:00         1         619
# 4        452  2024-10-06 00:00:00         1         619
# 5        452  2024-10-06 00:00:00         1         619
# 6        452  2024-10-06 00:00:00         1         619
# 7        452  2024-10-06 00:00:00         1         619
# 8        452  2024-10-06 00:00:00         1         619
# 9        452  2024-10-06 00:00:00         1         619
#
#                  DS_ELEICAO  ... CD_FLASHCARD_URNA_EFETIVADA  \
# 0  Eleições Municipais 2024  ...                    06B860E9
# 1  Eleições Municipais 2024  ...                    06B860E9
# 2  Eleições Municipais 2024  ...                    06B860E9
# 3  Eleições Municipais 2024  ...                    3312A024
# 4  Eleições Municipais 2024  ...                    06B860E9
# 5  Eleições Municipais 2024  ...                    3312A024
# 6  Eleições Municipais 2024  ...                    06B860E9
# 7  Eleições Municipais 2024  ...                    3312A024
# 8  Eleições Municipais 2024  ...                    06B860E9
# 9  Eleições Municipais 2024  ...                    06B860E9
#
#    DT_CARGA_URNA_EFETIVADA DS_CARGO_PERGUNTA_SECAO  DS_SECOES_AGREGADAS  \
# 0      2024-10-01 10:48:00                 13 - 79               #NULO#
# 1      2024-10-01 12:22:00                13 - 119               #NULO#
# 2      2024-10-01 10:15:00                 13 - 29                  156
# 3      2024-10-01 09:13:00                 13 - 87               #NULO#
# 4      2024-10-01 11:30:00                 13 - 87               #NULO#
# 5      2024-10-01 09:05:00                 13 - 68                  107
# 6      2024-10-01 09:45:00                 13 - 25               #NULO#
# 7      2024-10-01 09:28:00                13 - 120               #NULO#
# 8      2024-10-01 11:09:00                 13 - 85               #NULO#
# 9      2024-10-01 12:52:00                13 - 136                  139
#
#            DT_ABERTURA      DT_ENCERRAMENTO  QT_ELEI_BIOM_SEM_HABILITACAO  \
# 0  2024-10-06 08:00:01  2024-10-06 17:01:23                            18
# 1  2024-10-06 08:00:01  2024-10-06 17:08:41                            35
# 2  2024-10-06 08:00:01  2024-10-06 17:58:55                            34
# 3  2024-10-06 08:00:01  2024-10-06 17:04:34                            20
# 4  2024-10-06 08:00:01  2024-10-06 17:01:34                             7
# 5  2024-10-06 08:03:41  2024-10-06 17:01:57                            22
# 6  2024-10-06 08:00:01  2024-10-06 17:01:17                            28
# 7  2024-10-06 08:00:01  2024-10-06 17:01:41                            15
# 8  2024-10-06 08:00:01  2024-10-06 17:01:44                            26
# 9  2024-10-06 08:00:01  2024-10-06 17:04:29                            32
#
#          DT_EMISSAO_BU  NR_JUNTA_APURADORA NR_TURMA_APURADORA
# 0  2024-10-06 17:04:19                  -1                 -1
# 1  2024-10-06 17:10:10                  -1                 -1
# 2  2024-10-06 18:01:31                  -1                 -1
# 3  2024-10-06 17:06:20                  -1                 -1
# 4  2024-10-06 17:04:02                  -1                 -1
# 5  2024-10-06 17:05:35                  -1                 -1
# 6  2024-10-06 17:02:49                  -1                 -1
# 7  2024-10-06 17:04:20                  -1                 -1
# 8  2024-10-06 17:05:24                  -1                 -1
# 9  2024-10-06 17:06:38                  -1                 -1
#
# [10 rows x 45 columns]

# %%
df_boletim_urnas_pi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504685 entries, 0 to 504684
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   DT_GERACAO                    504685 non-null  object
#  1   HH_GERACAO                    504685 non-null  object
#  2   ANO_ELEICAO                   504685 non-null  int64
#  3   CD_TIPO_ELEICAO               504685 non-null  int64
#  4   NM_TIPO_ELEICAO               504685 non-null  object
#  5   CD_PLEITO                     504685 non-null  int64
#  6   DT_PLEITO                     504685 non-null  object
#  7   NR_TURNO                      504685 non-null  int64
#  8   CD_ELEICAO                    504685 non-null  int64
#  9   DS_ELEICAO                    504685 non-null  object
#  10  SG_UF                         504685 non-null  object
#  11  CD_MUNICIPIO                  504685 non-null  int64
#  12  NM_MUNICIPIO                  504685 non-null  object
#  13  NR_ZONA                       504685 non-null  int64
#  14  NR_SECAO                      504685 non-null  int64
#  15  NR_LOCAL_VOTACAO              504685 non-null  int64
#  16  CD_CARGO_PERGUNTA             504685 non-null  int64
#  17  DS_CARGO_PERGUNTA             504685 non-null  object
#  18  NR_PARTIDO                    504685 non-null  int64
#  19  SG_PARTIDO                    504685 non-null  object
#  20  NM_PARTIDO                    504685 non-null  object
#  21  DT_BU_RECEBIDO                504685 non-null  object
#  22  QT_APTOS                      504685 non-null  int64
#  23  QT_COMPARECIMENTO             504685 non-null  int64
#  24  QT_ABSTENCOES                 504685 non-null  int64
#  25  CD_TIPO_URNA                  504685 non-null  int64
#  26  DS_TIPO_URNA                  504685 non-null  object
#  27  CD_TIPO_VOTAVEL               504685 non-null  int64
#  28  DS_TIPO_VOTAVEL               504685 non-null  object
#  29  NR_VOTAVEL                    504685 non-null  int64
#  30  NM_VOTAVEL                    504685 non-null  object
#  31  QT_VOTOS                      504685 non-null  int64
#  32  NR_URNA_EFETIVADA             504685 non-null  int64
#  33  CD_CARGA_1_URNA_EFETIVADA     504685 non-null  object
#  34  CD_CARGA_2_URNA_EFETIVADA     504685 non-null  float64
#  35  CD_FLASHCARD_URNA_EFETIVADA   504685 non-null  object
#  36  DT_CARGA_URNA_EFETIVADA       504685 non-null  object
#  37  DS_CARGO_PERGUNTA_SECAO       504685 non-null  object
#  38  DS_SECOES_AGREGADAS           504685 non-null  object
#  39  DT_ABERTURA                   504685 non-null  object
#  40  DT_ENCERRAMENTO               504685 non-null  object
#  41  QT_ELEI_BIOM_SEM_HABILITACAO  504685 non-null  int64
#  42  DT_EMISSAO_BU                 504685 non-null  object
#  43  NR_JUNTA_APURADORA            504685 non-null  int64
#  44  NR_TURMA_APURADORA            504685 non-null  int64
# dtypes: float64(1), int64(22), object(22)
# memory usage: 173.3+ MB

# %% [markdown]
# ### Seleciona as colunas para análise

# %%
lista_colunas = ['NR_URNA_EFETIVADA','ANO_ELEICAO', 'NR_TURNO', 'SG_UF', 'NM_MUNICIPIO', 'CD_CARGO_PERGUNTA', 'NM_PARTIDO', 'QT_COMPARECIMENTO', 'QT_ABSTENCOES', 'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS']

# %% [markdown]
# ### Seleciona apenas os registros das urnas da cidade de Teresina

# %%
consulta_pi = "NM_MUNICIPIO=='TERESINA'"
df_urnas_teresina = df_boletim_urnas_pi[lista_colunas].query(consulta_pi)
df_urnas_teresina
# Out:
#         NR_URNA_EFETIVADA  ANO_ELEICAO  NR_TURNO SG_UF NM_MUNICIPIO  \
# 175               2399154         2024         1    PI     TERESINA
# 177               2359508         2024         1    PI     TERESINA
# 180               2362163         2024         1    PI     TERESINA
# 181               2397836         2024         1    PI     TERESINA
# 182               2411714         2024         1    PI     TERESINA
# ...                   ...          ...       ...   ...          ...
# 504541            2357364         2024         1    PI     TERESINA
# 504542            2345756         2024         1    PI     TERESINA
# 504544            2400158         2024         1    PI     TERESINA
# 504545            2359766         2024         1    PI     TERESINA
# 504546            2359766         2024         1    PI     TERESINA
#
#         CD_CARGO_PERGUNTA                                      NM_PARTIDO  \
# 175                    13                   Partido Socialista Brasileiro
# 177                    13                   Partido Socialista Brasileiro
# 180                    13  Partido Socialista dos Trabalhadores Unificado
# 181                    13                                       Cidadania
# 182                    13  Partido Socialista dos Trabalhadores Unificado
# ...                   ...                                             ...
# 504541                 13                Movimento Democrático Brasileiro
# 504542                 13                Movimento Democrático Brasileiro
# 504544                 13                Movimento Democrático Brasileiro
# 504545                 13                Movimento Democrático Brasileiro
# 504546                 13                                    União Brasil
#
#         QT_COMPARECIMENTO  QT_ABSTENCOES  NR_VOTAVEL      NM_VOTAVEL  QT_VOTOS
# 175                   265             57       40900  CORONEL AVELAR         1
# 177                   268             63       40900  CORONEL AVELAR         2
# 180                   237             31       16000    DANIEL SOLON         3
# 181                   304             77       23000   ROSIANE MATOS         1
# 182                   259             51       16000    DANIEL SOLON         1
# ...                   ...            ...         ...             ...       ...
# 504541                333             62       15101        PANTIKÃO         3
# 504542                342             54       15101        PANTIKÃO         3
# 504544                307             76       15101        PANTIKÃO         1
# 504545                291             32       15101        PANTIKÃO         1
# 504546                291             32       44456   DOUTOR LAZARO         1
#
# [202230 rows x 12 columns]

# %% [markdown]
# ### Nome dos candidatos que tiveram votos

# %%
df_urnas_teresina.NM_VOTAVEL.unique()
# Out:
# array(['CORONEL AVELAR', 'DANIEL SOLON', 'ROSIANE MATOS', 'FÁBIO DOURADO',
#        'VANDA TAVARES', 'ALUÍSIO SAMPAIO', 'DANIEL LOPES',
#        'THIAGO DUARTE', 'WAGNER TORRES', 'INSPETOR BARROS',
#        'PASTORA DIANA MUNIZ DO POVÃO', 'SOCORRO SILVA',
#        'WILDSON NOGUEIRA', 'DELEGADO ODILO SENA',
#        'FRANCISCO DOS APLICATIVOS', 'LUCIVANIA MUNDURI',
#        'PROF GIRLENO MARTINS', 'MARCOS MOURÃO', 'DOUTORA LARISSA',
#        'ELZUILA CALISTO', 'ANA LINA NERES', 'DEISE JACIELE',
#        'DRA. ANA CLAUDIA', 'CONTADORA WERIDIANA ARAUJO',
#        'FRANKLIN VINICIUS', 'DAIANE RODRIGUES', 'MARINA', 'FUZILA',
#        'NIVALDO OLIVEIRA', 'RICARDO PINTOR', 'JOAQUIM DO ARROZ',
#        'ROSANGELA BRITO', 'CAIO TORRES', 'TELSIRIO ALENCAR', 'DRA MAIA',
#        'ROZILENE LIMA', 'JUNIOR TRINCA', 'GIL DO BOTECO',
#        'CÉSAR MOTOTÁXI', 'DRA  ANDREIA', 'IDA GOMES', 'RUBENS CICLISTA',
#        'MARQUIM MONTEIRO', 'PEPITA', 'RAIMUNDO CASÉ',
#        'TERESINHA MEDEIROS', 'DRA ANA LÚCIA', 'CIDADANIA', 'ANDERSON GIL',
#        'VALDIVINO FOFÃO', 'FRANCISCO CHAGAS', 'Branco', 'BRUNO PESSOA',
#        'PROFESSOR AJOSÉ', 'NAIANE ALGARVES', 'MARQUINHO MAIA',
#        'GERALDO CARVALHO', 'PETRUS EVELYN', 'JUCA ALVES',
#        'POLIANA AGUIAR', 'PC do B', 'CELSO HENRIQUE', 'GERSON BARROS',
#        'PSOL', 'LAIANE MEIRELES', 'ARYADNE DANTAS', 'Nulo', 'NOVO',
#        'WILL TATTOO', 'RAVI CASTRO', 'CARLA MORAES', 'PRD', 'AGIR',
#        'ZÉ FILHO', 'GUSTAVO DE CARVALHO', 'PROFESSOR TONNY', 'REDE',
#        'MDB', 'PSTU', 'LUCAS DO BEM', 'REGINALDO SANTIAGO',
#        'PATRÍCIO GUILHERME', 'AVANTE', 'CÁSSIO',
#        'SAMMUEL SANTOS FILHODETERESINA', 'ETNIEL ANCHIETA',
#        'JURANDY DO QUEIJO', 'URDERIANA', 'TOBIAS', 'SGT R SILVA',
#        'KARLA SHYRLENY', 'MONICA BEZERRA', 'PROFESSOR ZÉ NITO',
#        'MIZAEL SOUSA', 'PROFESSOR JEAN', 'URBANO FILHO', 'CIRINEU LEMOS',
#        'FERNANDA FREITAS', 'NEGRA DILL', 'ENIO PORTELA',
#        'PROFESSOR JOSÉ GOMES', 'BICUDO', 'KARLA BERGER', 'SOCORRO ARRAES',
#        'PROFESSOR ASSIS LOPES', 'DALVA FERNANDES', 'CAP ROBERVAL QUEIROZ',
#        'CABEÇA BRANCA', 'DJALMA AMORIM', 'CLEITON POPULAR', 'PAULO LOPES',
#        'GUSTAVO HENRIQUE PELA CIDADE', 'FERNANDO LIMA', 'CHICO PANÇA',
#        'TATIANA MEDEIROS', 'MAZÉ DO VALE', 'ERLAN BASTOS',
#        'LEVINO DE JESUS', 'KARINA SOARES', 'GUSTAVO CAVALCANTE', 'PL',
#        'NIELSEN MATESCO', 'PV', 'ELISMARIO NASCIMENTO', 'NETO PEREIRA',
#        'ANTÔNIO CARLOS', 'PP', 'QUEIROZ DO JUDÔ',
#        'ELMANO O VEIN TRABALHADOR', 'ZÉ FREIRE', 'NEL LOPES',
#        'DANIEL CARVALHO', 'TENENTE CORONEL SARVIO', 'EVILÁSIO CORTEZ',
#        'VIGILANTE WALMIR SALVADOR', 'TIA EDNA', 'CONCEIÇÃO DA SAÚDE ',
#        'DRA LILIBETH', 'POLLYANNA ROCHA', 'VALDINA PIRES', 'LUIZA ARAÚJO',
#        'RENÊ BRASIL', 'SILVIO MENDES', 'YARA FERRY', 'CARPEJANNE GOMES',
#        'VALDEMIR VIRGINO', 'NILSIN', 'CAPITÃO EDMAR', 'WILSON MASCIEL',
#        'RONCALLIN', 'ENFERMEIRO ANTONIO NETO', 'PEDRO CIRQUEIRA',
#        'SOLIDARIEDADE', 'DOUTOR EZEQUIEL FILHO', 'PDT', 'JONATAS MIRANDA',
#        'PSDB', 'PT', 'EUGÊNIO PARAGUASSÚ GURGUEIA', 'PROFESSOR CANINDÉ',
#        'MAJOR PAULO ROBERTO', 'ANISIA TEIXEIRA DA MORADIA', 'UNIÃO',
#        'LUCILENE FERREIRA', 'ROSA PEREIRA', 'FÁTIMA NUNES',
#        'ISRAEL CARVALHO', 'LIVIA OLIVEIRA', 'LARISSA FREIRE',
#        'DÉBORA PAIVA', 'ANDERSON EMANUEL', 'JC DO GRANDE DIRCEU',
#        'TOINHO DUFRANGO', 'QUEM QUEM', 'LEONDIDAS JÚNIOR',
#        'VIRGÍNIA LEAL', 'CAMILA MARQUES', 'SANDRO CONRADO',
#        'LEILA DO POSTINHO', 'UP', 'DILSON RESENDE', 'BID LIMA',
#        'APARECIDA JUCÁ', 'JÚNIOR MACÊDO', 'CYNTIA FALCÃO',
#        'CLEMILTON DA SOCORRONA', 'ADRIANA CUNHA', 'FERNANDA GOMES',
#        'CARLOS ALMEIDA', 'DR LEONARDO EULALIO', 'JOTINHA',
#        'THIAGO VAZDACERTO', 'PASTORA SUELY', 'FLAVIANO CAMPOS',
#        'MARCELO SOUSA', 'MÉRCIA', 'JOSELITO DO KARATÊ', 'MARCUS MACEDO',
#        'VINICIO FERREIRA', 'SAMANTHA CAVALCA', 'WESLEY DEMES',
#        'JACELINE MAIA', 'ZILDA DA PALITOLANDIA', 'AURIMAR COSTA',
#        'PAULO AFONSO', 'MARINALVA SANTANA', 'VESPASIANO CARVALHO',
#        'ROBERTO BORGES', 'PROF JULIMAR', 'MAYRLA SILVA', 'CHIMBA',
#        'ISABELA ALVES', 'BIANCA SILVA', 'FELIPE PEDRO',
#        'NANDO DO LAR DO NANDO', 'ÉRICO DA LUTA', 'DR ERISVALDO',
#        'ANDERSON FERREIRA', 'RAFAEL DO PESQUEIRINHO', 'LUCY SOARES',
#        'PR CALEBE VERAS', 'ROBERTO MADEIRA', 'ANTONIO JOSÉ DA PAZ',
#        'FRANKLIN BATISTA', 'GENTIL OLIVEIRA', 'LALÁ DA PRAÇA',
#        'THAYS DIAS', 'MIRANDA NETO', 'DIONÍSIO PIAUÍ', 'DEOLINDO MOURA',
#        'DR RAFAEL', 'IGOR BARBOSA', 'RODRIGO CALDEIRA', 'SOCORRO MELO',
#        'GABRIELA BORGES', 'LUIS ANDRE', 'LUCIANA SEBIM', 'PANTIKÃO',
#        'DOUTOR LAZARO', 'GABRIEL BARBOSA', 'BARTOLOMEU DO CORUJÃO',
#        'GABRIELZIM', 'GRAÇA SANTOS ', 'EDUARDO DRAGA ALANA', 'DUDU',
#        'NILSON SANTOS', 'CORONEL LÍDIO FILHO', 'CORONEL NIXON',
#        'VALDEMAR DA PENHA', 'FRANCINALDO LEÃO', 'HUMBERTO ROLDÃO',
#        'CRUIZINHA REIS', 'JACIEL SILVA', 'PSD', 'CARLINHOS DA BISS',
#        'DR LIVIO MACHADO', 'FELIPE FERNANDES', 'DC', 'CAMILA CASTRO',
#        'PROFESSOR CHAGUINHA', 'FERREIRA', 'CHICAO DONA MARIA',
#        'DR. SAMUEL RÊGO', 'PROFESSOR ANTÔNIO', 'CARLOS RIBEIRO',
#        'SÉRGIO BANDEIRA', 'HENRIQUE REBELLO', 'EVANDRO MARQUES',
#        'MÁRCIA VILA NOVA', 'CRISTIANE KELLMA', 'ALDO SANDRO',
#        'WILSON DA EDUCAÇÃO', 'CAETANO', 'GABRIEL COSTA', 'CARLOS NENEM',
#        'MARCOS AURÉLIO', 'RAIFRAN OLIVEIRA', 'ZÉ BECA',
#        'DR PAULO HENRIQUE DA SAÚDE', "JOANA D'ARC", 'PEDRO JUNIOR',
#        'SÉFORA FERREIRA', 'ELDIN DO DIRCEU', 'MISSIONÁRIO BILL SANTOS',
#        'ALEXANDRE ALMEIDA', 'ALAN BRANDÃO', 'CÍCERO MAGALHÃES',
#        'SAMUEL COÊLHO', 'EDU AGUIAR', 'FRANCISCO PELA IGUALDADE',
#        'ALDO COSTA', 'FABIO ANDRADE', 'BRUNO OLIVEIRA', 'TEÔNIA',
#        'IASMINNE PINHEIRO', 'IRMÃO LUIZ MARINHO', 'THIAGO NUNES',
#        'ANTONIA MARIA', 'NEIVA JÚNIOR', 'COCHISE', 'DENISE TRIGUEIRO',
#        'LUCÉLIA CAMPOS', 'JÚNIORMPTRÊS', 'CORONEL ARAÚJO DO CATE',
#        'GERALDIN', 'CARLOS ALBERTO', 'LUCINHA LIMA', 'ANA FIDELIS',
#        'LYTSON BRENO', 'MISSIONÁRIO JOÃO BATISTA', 'LÍVIA MARIA',
#        'TIAGO SILVA', 'SOCORRO DA CLÍNICA', 'FABRÍCIO CAMELÔ',
#        'ISMAEL SILVA', 'FLORO DO THEMOS VAGAS', 'ERISVALDO RODRIGUES',
#        'FRANCISCO SOUSA ', 'PROFESSOR ERICK RICCELY', 'FABIOLA',
#        'AMARILDO JÚNIOR', 'IRMÃO SÉRGIO', 'THALES DO TERÇO',
#        'JOÃO PEREIRA', 'SARGENTO IVO', 'FÁBIO ALVES', 'PLACIDO FERREIRA',
#        'YURE MOUSINHO', 'FÁTIMA DO IDOSO', 'PROFESSOR ALBERTO MACHADO',
#        'GRAÇA AMORIM', 'SANTIAGO BELIZARIO', 'ELIAS BATISTA',
#        'FABRÍCIO AURÉLIO', 'ZÉ DA LUZ PARAÍBA', 'FABRÍCIO DOURADO',
#        'SCHEYVAN', 'SARGENTO JUNIOR PAGODEIRO', 'VENANCIO', 'BEBETO NETO',
#        'DIOMAR JULIA', 'PEDRO FERNANDES', 'THANANDRA SARAPATINHAS',
#        'SAMARA PEREIRA', 'CARLA CLÉIA', 'LÉO CASTELLO',
#        'ANA CÉLIA ARAGÃO', 'LUCIANO PORTELA', 'IRMÃO JESUS', 'J FRANCO',
#        'FABIO NOVO', 'FRANCINETE VAZ', 'BOB GUERREIRO',
#        'VERONICA DO POVO', 'ZÉ NETO', 'PASTOR WOLNEY NOGUEIRA',
#        'IRMÃO ELIAS', 'JEAN ABREU', 'HASSAN', 'INACIO CARVALHO',
#        'NETO DO ANGELIM', 'GONÇALINHO', 'EDSON BARBOSA',
#        'ARTENIO FERREIRA', 'PAULO ROBERTO DA ILUMINAÇÃO',
#        'CHARLES RESENDE', 'FERDINAND DO MOCAMBINHO', 'SIMONE SILVA',
#        'JANARA RIBEIRO', 'MIGUELZIN', 'MICHELLY MOREIRA',
#        'ALLAN RODRIGUES', 'DANNY BARRADAS', 'PEDRO VIDAL', 'ZEFA',
#        'PROFA ROSILEIDE RIOS', 'DJAN MOREIRA', 'ZÉ DA CRUZ',
#        'GEYCE CARVALHO', 'RONALDO MENDES', 'LENILSON VIEIRA',
#        'FÁTIMA DUARTE', 'ISAC DO CENTRO', 'HEDILENE NASSIL',
#        'JÚLIO LEITE', 'MISSIONÁRIA GERCILANE', 'SUELY',
#        'GHISLAYNE CAVALCANTE', 'ALDENICE DEDÉ', 'NILSON CAVALCANTE',
#        'MÁRCIA GARDÊNIA', 'CHICÃO FREITAS', 'PROFª JANETE',
#        'DILSON MARQUES', 'ROBERT IBIAPINA',
#        'ZÉ DOS SANTOS - O ZEZO PIAUÍ', 'JOHN WALLACE',
#        'ANTONIO JOSÉ LIRA', 'MARIA DA BANCADA ANTIRRACISTA',
#        'JESUS RODRIGUES', 'VAL VIEIRA', 'TOINHA PÉ QUENTE',
#        'GERSON VELOSO', 'ALBERT IBIAPINA',
#        'DR PAULO LINHARES DA EDUCAÇÃO', 'EDNA BARRADAS-TIA EDINHA',
#        'ALLISSON ARAGÃO CHAPA COLETIVA', 'SARGENTO WENDELL',
#        'PEDRO ALCANTARA', 'PROFESSORA ROSÁRIO BORGES', 'BENEDITA',
#        'PASTORA RAQUEL', 'DELEGADO JAMES GUERRA',
#        'CAMILLA ROSAL DA REGULARIZAÇÃO', 'ROSENÁRIA',
#        'RIBAMAR RODRIGUES ', 'IARA', 'JOSE MARIA', 'SARGENTA GALIANA',
#        'EVANDRO HIDD', 'PAULO FARMACÊUTICO', 'BRUNO VILARINHO',
#        'MOTORISTA FRANK', 'GESSY LIMA', 'TINA DUARTE', 'SGT CHICO MACALÉ',
#        'JAIR SAMPAIO ', 'MIKIBA', 'FRED SANTANA', 'JUJU DO TRANSITO',
#        'GRAÇA MORAIS', 'HALLYSON MATA', 'RILMA RIOS', 'VÂNIA ARAÚJO',
#        'ROSA', 'GUILHERME XAVIER', 'LOURDES MELO', 'DANIEL PEREIRA',
#        'PROFESSORA SHUELING AMARAL', 'MARLENE RIBEIRO',
#        'ADRIANA DA GRAÇA', 'JOSUILA BRITO', 'DANILIM', 'PODE',
#        'ENZO SAMUEL', 'ORLANDO MATIAS', 'FERNANDA AZEVÊDO',
#        'DECIO SOLANO', 'LAFAYETTE ANDRADE', 'PAULA-MISSIONARIA PAULA',
#        'MARCELO FISCAL', 'DRA ALZIRA DE PÁDUA', 'WELLINGTON OLIVEIRA',
#        'FELIPE RIPARDO', 'ZÉ FRANCIS', 'RAÍSSA PROTETORA',
#        'DAGMAR DOS ANJOS', 'VALDECI MELLO', 'ZÉ DIREITA',
#        'MACELLO FONSECA', 'PASTORA IANA CUNHA', 'MIGUEL OSÓRIO',
#        'LUIS GONZAGA', 'DR PESSOA', 'DORINHA DA PAZ', 'DR. LUIZ LOBÃO',
#        'LUIS ROSA', 'CARLOS PIMENTEL', 'FARIAS ROGERIO', 'DENISE ALMEIDA',
#        'MANOEL CADEIRANTE', 'ANDRÉ MESQUITA', 'SEU JÚNIOR',
#        'JUNIOR PIMENTÃO', 'PROFESSORA JOANA', 'ROBERTO SILVA',
#        'PASTOR CARLOS', 'CAIO BUCAR', 'IRMÃO LIMA', 'HARRY BEZERRA',
#        'LUCIANO KASSAROLA', 'ALLAN CAVALCANTE', 'RENATO BERGER',
#        'PRISCILA THUANE', 'THAIS MOURA', 'MARCELO CAPOEIRA',
#        'CELIA GOMES', 'ANA CRISTINA DO CAMBOA', 'DAVID DA GENTE',
#        'DOUGLAS ALEXANDRE', 'CHICO GOMES', 'SAMUEL ALENCAR',
#        'TANYA DO PIAUÍ', 'DR. THIAGO SAMPAIO', 'ELEUZA DIAS',
#        'ENEIAS MORAES', 'ITALO BEZERRA', 'VAL RIBEIRO', 'FRANCISCA NEVES',
#        'RONALDO CHAVES', 'MARCELO MAPIX', 'PASTOR ROBSON SILVA',
#        'INÁCIA IZABEL BENTA DE ASSIS', 'PSB', 'REPUBLICANOS'],
#       dtype=object)

# %%
lista_candidatos = df_urnas_teresina.NM_VOTAVEL.unique().tolist()
lista_candidatos
# Out:
# ['CORONEL AVELAR',
#  'DANIEL SOLON',
#  'ROSIANE MATOS',
#  'FÁBIO DOURADO',
#  'VANDA TAVARES',
#  'ALUÍSIO SAMPAIO',
#  'DANIEL LOPES',
#  'THIAGO DUARTE',
#  'WAGNER TORRES',
#  'INSPETOR BARROS',
#  'PASTORA DIANA MUNIZ DO POVÃO',
#  'SOCORRO SILVA',
#  'WILDSON NOGUEIRA',
#  'DELEGADO ODILO SENA',
#  'FRANCISCO DOS APLICATIVOS',
#  'LUCIVANIA MUNDURI',
#  'PROF GIRLENO MARTINS',
#  'MARCOS MOURÃO',
#  'DOUTORA LARISSA',
#  'ELZUILA CALISTO',
#  'ANA LINA NERES',
#  'DEISE JACIELE',
#  'DRA. ANA CLAUDIA',
#  'CONTADORA WERIDIANA ARAUJO',
#  'FRANKLIN VINICIUS',
#  'DAIANE RODRIGUES',
#  'MARINA',
#  'FUZILA',
#  'NIVALDO OLIVEIRA',
#  'RICARDO PINTOR',
#  'JOAQUIM DO ARROZ',
#  'ROSANGELA BRITO',
#  'CAIO TORRES',
#  'TELSIRIO ALENCAR',
#  'DRA MAIA',
#  'ROZILENE LIMA',
#  'JUNIOR TRINCA',
#  'GIL DO BOTECO',
#  'CÉSAR MOTOTÁXI',
#  'DRA  ANDREIA',
#  'IDA GOMES',
#  'RUBENS CICLISTA',
#  'MARQUIM MONTEIRO',
#  'PEPITA',
#  'RAIMUNDO CASÉ',
#  'TERESINHA MEDEIROS',
#  'DRA ANA LÚCIA',
#  'CIDADANIA',
#  'ANDERSON GIL',
#  'VALDIVINO FOFÃO',
#  'FRANCISCO CHAGAS',
#  'Branco',
#  'BRUNO PESSOA',
#  'PROFESSOR AJOSÉ',
#  'NAIANE ALGARVES',
#  'MARQUINHO MAIA',
#  'GERALDO CARVALHO',
#  'PETRUS EVELYN',
#  'JUCA ALVES',
#  'POLIANA AGUIAR',
#  'PC do B',
#  'CELSO HENRIQUE',
#  'GERSON BARROS',
#  'PSOL',
#  'LAIANE MEIRELES',
#  'ARYADNE DANTAS',
#  'Nulo',
#  'NOVO',
#  'WILL TATTOO',
#  'RAVI CASTRO',
#  'CARLA MORAES',
#  'PRD',
#  'AGIR',
#  'ZÉ FILHO',
#  'GUSTAVO DE CARVALHO',
#  'PROFESSOR TONNY',
#  'REDE',
#  'MDB',
#  'PSTU',
#  'LUCAS DO BEM',
#  'REGINALDO SANTIAGO',
#  'PATRÍCIO GUILHERME',
#  'AVANTE',
#  'CÁSSIO',
#  'SAMMUEL SANTOS FILHODETERESINA',
#  'ETNIEL ANCHIETA',
#  'JURANDY DO QUEIJO',
#  'URDERIANA',
#  'TOBIAS',
#  'SGT R SILVA',
#  'KARLA SHYRLENY',
#  'MONICA BEZERRA',
#  'PROFESSOR ZÉ NITO',
#  'MIZAEL SOUSA',
#  'PROFESSOR JEAN',
#  'URBANO FILHO',
#  'CIRINEU LEMOS',
#  'FERNANDA FREITAS',
#  'NEGRA DILL',
#  'ENIO PORTELA',
#  'PROFESSOR JOSÉ GOMES',
#  'BICUDO',
#  'KARLA BERGER',
#  'SOCORRO ARRAES',
#  'PROFESSOR ASSIS LOPES',
#  'DALVA FERNANDES',
#  'CAP ROBERVAL QUEIROZ',
#  'CABEÇA BRANCA',
#  'DJALMA AMORIM',
#  'CLEITON POPULAR',
#  'PAULO LOPES',
#  'GUSTAVO HENRIQUE PELA CIDADE',
#  'FERNANDO LIMA',
#  'CHICO PANÇA',
#  'TATIANA MEDEIROS',
#  'MAZÉ DO VALE',
#  'ERLAN BASTOS',
#  'LEVINO DE JESUS',
#  'KARINA SOARES',
#  'GUSTAVO CAVALCANTE',
#  'PL',
#  'NIELSEN MATESCO',
#  'PV',
#  'ELISMARIO NASCIMENTO',
#  'NETO PEREIRA',
#  'ANTÔNIO CARLOS',
#  'PP',
#  'QUEIROZ DO JUDÔ',
#  'ELMANO O VEIN TRABALHADOR',
#  'ZÉ FREIRE',
#  'NEL LOPES',
#  'DANIEL CARVALHO',
#  'TENENTE CORONEL SARVIO',
#  'EVILÁSIO CORTEZ',
#  'VIGILANTE WALMIR SALVADOR',
#  'TIA EDNA',
#  'CONCEIÇÃO DA SAÚDE ',
#  'DRA LILIBETH',
#  'POLLYANNA ROCHA',
#  'VALDINA PIRES',
#  'LUIZA ARAÚJO',
#  'RENÊ BRASIL',
#  'SILVIO MENDES',
#  'YARA FERRY',
#  'CARPEJANNE GOMES',
#  'VALDEMIR VIRGINO',
#  'NILSIN',
#  'CAPITÃO EDMAR',
#  'WILSON MASCIEL',
#  'RONCALLIN',
#  'ENFERMEIRO ANTONIO NETO',
#  'PEDRO CIRQUEIRA',
#  'SOLIDARIEDADE',
#  'DOUTOR EZEQUIEL FILHO',
#  'PDT',
#  'JONATAS MIRANDA',
#  'PSDB',
#  'PT',
#  'EUGÊNIO PARAGUASSÚ GURGUEIA',
#  'PROFESSOR CANINDÉ',
#  'MAJOR PAULO ROBERTO',
#  'ANISIA TEIXEIRA DA MORADIA',
#  'UNIÃO',
#  'LUCILENE FERREIRA',
#  'ROSA PEREIRA',
#  'FÁTIMA NUNES',
#  'ISRAEL CARVALHO',
#  'LIVIA OLIVEIRA',
#  'LARISSA FREIRE',
#  'DÉBORA PAIVA',
#  'ANDERSON EMANUEL',
#  'JC DO GRANDE DIRCEU',
#  'TOINHO DUFRANGO',
#  'QUEM QUEM',
#  'LEONDIDAS JÚNIOR',
#  'VIRGÍNIA LEAL',
#  'CAMILA MARQUES',
#  'SANDRO CONRADO',
#  'LEILA DO POSTINHO',
#  'UP',
#  'DILSON RESENDE',
#  'BID LIMA',
#  'APARECIDA JUCÁ',
#  'JÚNIOR MACÊDO',
#  'CYNTIA FALCÃO',
#  'CLEMILTON DA SOCORRONA',
#  'ADRIANA CUNHA',
#  'FERNANDA GOMES',
#  'CARLOS ALMEIDA',
#  'DR LEONARDO EULALIO',
#  'JOTINHA',
#  'THIAGO VAZDACERTO',
#  'PASTORA SUELY',
#  'FLAVIANO CAMPOS',
#  'MARCELO SOUSA',
#  'MÉRCIA',
#  'JOSELITO DO KARATÊ',
#  'MARCUS MACEDO',
#  'VINICIO FERREIRA',
#  'SAMANTHA CAVALCA',
#  'WESLEY DEMES',
#  'JACELINE MAIA',
#  'ZILDA DA PALITOLANDIA',
#  'AURIMAR COSTA',
#  'PAULO AFONSO',
#  'MARINALVA SANTANA',
#  'VESPASIANO CARVALHO',
#  'ROBERTO BORGES',
#  'PROF JULIMAR',
#  'MAYRLA SILVA',
#  'CHIMBA',
#  'ISABELA ALVES',
#  'BIANCA SILVA',
#  'FELIPE PEDRO',
#  'NANDO DO LAR DO NANDO',
#  'ÉRICO DA LUTA',
#  'DR ERISVALDO',
#  'ANDERSON FERREIRA',
#  'RAFAEL DO PESQUEIRINHO',
#  'LUCY SOARES',
#  'PR CALEBE VERAS',
#  'ROBERTO MADEIRA',
#  'ANTONIO JOSÉ DA PAZ',
#  'FRANKLIN BATISTA',
#  'GENTIL OLIVEIRA',
#  'LALÁ DA PRAÇA',
#  'THAYS DIAS',
#  'MIRANDA NETO',
#  'DIONÍSIO PIAUÍ',
#  'DEOLINDO MOURA',
#  'DR RAFAEL',
#  'IGOR BARBOSA',
#  'RODRIGO CALDEIRA',
#  'SOCORRO MELO',
#  'GABRIELA BORGES',
#  'LUIS ANDRE',
#  'LUCIANA SEBIM',
#  'PANTIKÃO',
#  'DOUTOR LAZARO',
#  'GABRIEL BARBOSA',
#  'BARTOLOMEU DO CORUJÃO',
#  'GABRIELZIM',
#  'GRAÇA SANTOS ',
#  'EDUARDO DRAGA ALANA',
#  'DUDU',
#  'NILSON SANTOS',
#  'CORONEL LÍDIO FILHO',
#  'CORONEL NIXON',
#  'VALDEMAR DA PENHA',
#  'FRANCINALDO LEÃO',
#  'HUMBERTO ROLDÃO',
#  'CRUIZINHA REIS',
#  'JACIEL SILVA',
#  'PSD',
#  'CARLINHOS DA BISS',
#  'DR LIVIO MACHADO',
#  'FELIPE FERNANDES',
#  'DC',
#  'CAMILA CASTRO',
#  'PROFESSOR CHAGUINHA',
#  'FERREIRA',
#  'CHICAO DONA MARIA',
#  'DR. SAMUEL RÊGO',
#  'PROFESSOR ANTÔNIO',
#  'CARLOS RIBEIRO',
#  'SÉRGIO BANDEIRA',
#  'HENRIQUE REBELLO',
#  'EVANDRO MARQUES',
#  'MÁRCIA VILA NOVA',
#  'CRISTIANE KELLMA',
#  'ALDO SANDRO',
#  'WILSON DA EDUCAÇÃO',
#  'CAETANO',
#  'GABRIEL COSTA',
#  'CARLOS NENEM',
#  'MARCOS AURÉLIO',
#  'RAIFRAN OLIVEIRA',
#  'ZÉ BECA',
#  'DR PAULO HENRIQUE DA SAÚDE',
#  "JOANA D'ARC",
#  'PEDRO JUNIOR',
#  'SÉFORA FERREIRA',
#  'ELDIN DO DIRCEU',
#  'MISSIONÁRIO BILL SANTOS',
#  'ALEXANDRE ALMEIDA',
#  'ALAN BRANDÃO',
#  'CÍCERO MAGALHÃES',
#  'SAMUEL COÊLHO',
#  'EDU AGUIAR',
#  'FRANCISCO PELA IGUALDADE',
#  'ALDO COSTA',
#  'FABIO ANDRADE',
#  'BRUNO OLIVEIRA',
#  'TEÔNIA',
#  'IASMINNE PINHEIRO',
#  'IRMÃO LUIZ MARINHO',
#  'THIAGO NUNES',
#  'ANTONIA MARIA',
#  'NEIVA JÚNIOR',
#  'COCHISE',
#  'DENISE TRIGUEIRO',
#  'LUCÉLIA CAMPOS',
#  'JÚNIORMPTRÊS',
#  'CORONEL ARAÚJO DO CATE',
#  'GERALDIN',
#  'CARLOS ALBERTO',
#  'LUCINHA LIMA',
#  'ANA FIDELIS',
#  'LYTSON BRENO',
#  'MISSIONÁRIO JOÃO BATISTA',
#  'LÍVIA MARIA',
#  'TIAGO SILVA',
#  'SOCORRO DA CLÍNICA',
#  'FABRÍCIO CAMELÔ',
#  'ISMAEL SILVA',
#  'FLORO DO THEMOS VAGAS',
#  'ERISVALDO RODRIGUES',
#  'FRANCISCO SOUSA ',
#  'PROFESSOR ERICK RICCELY',
#  'FABIOLA',
#  'AMARILDO JÚNIOR',
#  'IRMÃO SÉRGIO',
#  'THALES DO TERÇO',
#  'JOÃO PEREIRA',
#  'SARGENTO IVO',
#  'FÁBIO ALVES',
#  'PLACIDO FERREIRA',
#  'YURE MOUSINHO',
#  'FÁTIMA DO IDOSO',
#  'PROFESSOR ALBERTO MACHADO',
#  'GRAÇA AMORIM',
#  'SANTIAGO BELIZARIO',
#  'ELIAS BATISTA',
#  'FABRÍCIO AURÉLIO',
#  'ZÉ DA LUZ PARAÍBA',
#  'FABRÍCIO DOURADO',
#  'SCHEYVAN',
#  'SARGENTO JUNIOR PAGODEIRO',
#  'VENANCIO',
#  'BEBETO NETO',
#  'DIOMAR JULIA',
#  'PEDRO FERNANDES',
#  'THANANDRA SARAPATINHAS',
#  'SAMARA PEREIRA',
#  'CARLA CLÉIA',
#  'LÉO CASTELLO',
#  'ANA CÉLIA ARAGÃO',
#  'LUCIANO PORTELA',
#  'IRMÃO JESUS',
#  'J FRANCO',
#  'FABIO NOVO',
#  'FRANCINETE VAZ',
#  'BOB GUERREIRO',
#  'VERONICA DO POVO',
#  'ZÉ NETO',
#  'PASTOR WOLNEY NOGUEIRA',
#  'IRMÃO ELIAS',
#  'JEAN ABREU',
#  'HASSAN',
#  'INACIO CARVALHO',
#  'NETO DO ANGELIM',
#  'GONÇALINHO',
#  'EDSON BARBOSA',
#  'ARTENIO FERREIRA',
#  'PAULO ROBERTO DA ILUMINAÇÃO',
#  'CHARLES RESENDE',
#  'FERDINAND DO MOCAMBINHO',
#  'SIMONE SILVA',
#  'JANARA RIBEIRO',
#  'MIGUELZIN',
#  'MICHELLY MOREIRA',
#  'ALLAN RODRIGUES',
#  'DANNY BARRADAS',
#  'PEDRO VIDAL',
#  'ZEFA',
#  'PROFA ROSILEIDE RIOS',
#  'DJAN MOREIRA',
#  'ZÉ DA CRUZ',
#  'GEYCE CARVALHO',
#  'RONALDO MENDES',
#  'LENILSON VIEIRA',
#  'FÁTIMA DUARTE',
#  'ISAC DO CENTRO',
#  'HEDILENE NASSIL',
#  'JÚLIO LEITE',
#  'MISSIONÁRIA GERCILANE',
#  'SUELY',
#  'GHISLAYNE CAVALCANTE',
#  'ALDENICE DEDÉ',
#  'NILSON CAVALCANTE',
#  'MÁRCIA GARDÊNIA',
#  'CHICÃO FREITAS',
#  'PROFª JANETE',
#  'DILSON MARQUES',
#  'ROBERT IBIAPINA',
#  'ZÉ DOS SANTOS - O ZEZO PIAUÍ',
#  'JOHN WALLACE',
#  'ANTONIO JOSÉ LIRA',
#  'MARIA DA BANCADA ANTIRRACISTA',
#  'JESUS RODRIGUES',
#  'VAL VIEIRA',
#  'TOINHA PÉ QUENTE',
#  'GERSON VELOSO',
#  'ALBERT IBIAPINA',
#  'DR PAULO LINHARES DA EDUCAÇÃO',
#  'EDNA BARRADAS-TIA EDINHA',
#  'ALLISSON ARAGÃO CHAPA COLETIVA',
#  'SARGENTO WENDELL',
#  'PEDRO ALCANTARA',
#  'PROFESSORA ROSÁRIO BORGES',
#  'BENEDITA',
#  'PASTORA RAQUEL',
#  'DELEGADO JAMES GUERRA',
#  'CAMILLA ROSAL DA REGULARIZAÇÃO',
#  'ROSENÁRIA',
#  'RIBAMAR RODRIGUES ',
#  'IARA',
#  'JOSE MARIA',
#  'SARGENTA GALIANA',
#  'EVANDRO HIDD',
#  'PAULO FARMACÊUTICO',
#  'BRUNO VILARINHO',
#  'MOTORISTA FRANK',
#  'GESSY LIMA',
#  'TINA DUARTE',
#  'SGT CHICO MACALÉ',
#  'JAIR SAMPAIO ',
#  'MIKIBA',
#  'FRED SANTANA',
#  'JUJU DO TRANSITO',
#  'GRAÇA MORAIS',
#  'HALLYSON MATA',
#  'RILMA RIOS',
#  'VÂNIA ARAÚJO',
#  'ROSA',
#  'GUILHERME XAVIER',
#  'LOURDES MELO',
#  'DANIEL PEREIRA',
#  'PROFESSORA SHUELING AMARAL',
#  'MARLENE RIBEIRO',
#  'ADRIANA DA GRAÇA',
#  'JOSUILA BRITO',
#  'DANILIM',
#  'PODE',
#  'ENZO SAMUEL',
#  'ORLANDO MATIAS',
#  'FERNANDA AZEVÊDO',
#  'DECIO SOLANO',
#  'LAFAYETTE ANDRADE',
#  'PAULA-MISSIONARIA PAULA',
#  'MARCELO FISCAL',
#  'DRA ALZIRA DE PÁDUA',
#  'WELLINGTON OLIVEIRA',
#  'FELIPE RIPARDO',
#  'ZÉ FRANCIS',
#  'RAÍSSA PROTETORA',
#  'DAGMAR DOS ANJOS',
#  'VALDECI MELLO',
#  'ZÉ DIREITA',
#  'MACELLO FONSECA',
#  'PASTORA IANA CUNHA',
#  'MIGUEL OSÓRIO',
#  'LUIS GONZAGA',
#  'DR PESSOA',
#  'DORINHA DA PAZ',
#  'DR. LUIZ LOBÃO',
#  'LUIS ROSA',
#  'CARLOS PIMENTEL',
#  'FARIAS ROGERIO',
#  'DENISE ALMEIDA',
#  'MANOEL CADEIRANTE',
#  'ANDRÉ MESQUITA',
#  'SEU JÚNIOR',
#  'JUNIOR PIMENTÃO',
#  'PROFESSORA JOANA',
#  'ROBERTO SILVA',
#  'PASTOR CARLOS',
#  'CAIO BUCAR',
#  'IRMÃO LIMA',
#  'HARRY BEZERRA',
#  'LUCIANO KASSAROLA',
#  'ALLAN CAVALCANTE',
#  'RENATO BERGER',
#  'PRISCILA THUANE',
#  'THAIS MOURA',
#  'MARCELO CAPOEIRA',
#  'CELIA GOMES',
#  'ANA CRISTINA DO CAMBOA',
#  'DAVID DA GENTE',
#  'DOUGLAS ALEXANDRE',
#  'CHICO GOMES',
#  'SAMUEL ALENCAR',
#  'TANYA DO PIAUÍ',
#  'DR. THIAGO SAMPAIO',
#  'ELEUZA DIAS',
#  'ENEIAS MORAES',
#  'ITALO BEZERRA',
#  'VAL RIBEIRO',
#  'FRANCISCA NEVES',
#  'RONALDO CHAVES',
#  'MARCELO MAPIX',
#  'PASTOR ROBSON SILVA',
#  'INÁCIA IZABEL BENTA DE ASSIS',
#  'PSB',
#  'REPUBLICANOS']

# %% [markdown]
# ### Qtd de votos do candidato Silvio Mendes

# %%
df_silvio_mendes = df_urnas_teresina.query("NM_VOTAVEL=='SILVIO MENDES'")
df_silvio_mendes
# Out:
#         NR_URNA_EFETIVADA  ANO_ELEICAO  NR_TURNO SG_UF NM_MUNICIPIO  \
# 60188             2412322         2024         1    PI     TERESINA
# 60189             2412964         2024         1    PI     TERESINA
# 60190             2343293         2024         1    PI     TERESINA
# 60191             2400198         2024         1    PI     TERESINA
# 60192             2396530         2024         1    PI     TERESINA
# ...                   ...          ...       ...   ...          ...
# 413149            2350621         2024         1    PI     TERESINA
# 413150            2337617         2024         1    PI     TERESINA
# 413151            2410846         2024         1    PI     TERESINA
# 413152            2337653         2024         1    PI     TERESINA
# 413153            2398921         2024         1    PI     TERESINA
#
#         CD_CARGO_PERGUNTA    NM_PARTIDO  QT_COMPARECIMENTO  QT_ABSTENCOES  \
# 60188                  11  União Brasil                304             80
# 60189                  11  União Brasil                298             64
# 60190                  11  União Brasil                314             52
# 60191                  11  União Brasil                321             55
# 60192                  11  União Brasil                256             33
# ...                   ...           ...                ...            ...
# 413149                 11  União Brasil                336             51
# 413150                 11  União Brasil                257             65
# 413151                 11  União Brasil                294             46
# 413152                 11  União Brasil                346             61
# 413153                 11  União Brasil                215             54
#
#         NR_VOTAVEL     NM_VOTAVEL  QT_VOTOS
# 60188           44  SILVIO MENDES       170
# 60189           44  SILVIO MENDES       154
# 60190           44  SILVIO MENDES       130
# 60191           44  SILVIO MENDES       185
# 60192           44  SILVIO MENDES       112
# ...            ...            ...       ...
# 413149          44  SILVIO MENDES       180
# 413150          44  SILVIO MENDES       143
# 413151          44  SILVIO MENDES       166
# 413152          44  SILVIO MENDES       191
# 413153          44  SILVIO MENDES       105
#
# [1701 rows x 12 columns]

# %%
df_silvio_mendes.QT_VOTOS
# Out:
# 60188     170
# 60189     154
# 60190     130
# 60191     185
# 60192     112
#          ...
# 413149    180
# 413150    143
# 413151    166
# 413152    191
# 413153    105
# Name: QT_VOTOS, Length: 1701, dtype: int64

# %%
df_silvio_mendes.QT_VOTOS.sum()
# Out:
# 239848

# %% [markdown]
# ### Quantidade de votos do candidato Fábio Novo

# %%
df_fabio_novo = df_urnas_teresina.query("NM_VOTAVEL=='FABIO NOVO'")

# %%
df_fabio_novo
# Out:
#         NR_URNA_EFETIVADA  ANO_ELEICAO  NR_TURNO SG_UF NM_MUNICIPIO  \
# 116920            2408638         2024         1    PI     TERESINA
# 116922            2464412         2024         1    PI     TERESINA
# 116923            2359034         2024         1    PI     TERESINA
# 116925            2356548         2024         1    PI     TERESINA
# 116926            2460352         2024         1    PI     TERESINA
# ...                   ...          ...       ...   ...          ...
# 495552            2411945         2024         1    PI     TERESINA
# 495553            2400156         2024         1    PI     TERESINA
# 495554            2358129         2024         1    PI     TERESINA
# 495555            2400324         2024         1    PI     TERESINA
# 495556            2410231         2024         1    PI     TERESINA
#
#         CD_CARGO_PERGUNTA                 NM_PARTIDO  QT_COMPARECIMENTO  \
# 116920                 11  Partido dos Trabalhadores                284
# 116922                 11  Partido dos Trabalhadores                284
# 116923                 11  Partido dos Trabalhadores                257
# 116925                 11  Partido dos Trabalhadores                315
# 116926                 11  Partido dos Trabalhadores                318
# ...                   ...                        ...                ...
# 495552                 11  Partido dos Trabalhadores                302
# 495553                 11  Partido dos Trabalhadores                325
# 495554                 11  Partido dos Trabalhadores                257
# 495555                 11  Partido dos Trabalhadores                305
# 495556                 11  Partido dos Trabalhadores                296
#
#         QT_ABSTENCOES  NR_VOTAVEL  NM_VOTAVEL  QT_VOTOS
# 116920             36          13  FABIO NOVO       129
# 116922             57          13  FABIO NOVO        96
# 116923             34          13  FABIO NOVO       157
# 116925             74          13  FABIO NOVO       121
# 116926             74          13  FABIO NOVO       122
# ...               ...         ...         ...       ...
# 495552             84          13  FABIO NOVO        97
# 495553             56          13  FABIO NOVO       171
# 495554             88          13  FABIO NOVO        60
# 495555             79          13  FABIO NOVO        90
# 495556             50          13  FABIO NOVO       128
#
# [1701 rows x 12 columns]

# %%
df_fabio_novo.QT_VOTOS
# Out:
# 116920    129
# 116922     96
# 116923    157
# 116925    121
# 116926    122
#          ...
# 495552     97
# 495553    171
# 495554     60
# 495555     90
# 495556    128
# Name: QT_VOTOS, Length: 1701, dtype: int64

# %%
df_fabio_novo.QT_VOTOS.sum()
# Out:
# 198794

# %% [markdown]
# ### Quantidade de votos candidato Dr. Pessoa

# %%
df_dr_pessoa = df_urnas_teresina.query("NM_VOTAVEL=='DR PESSOA'")

# %%
df_dr_pessoa
# Out:
#         NR_URNA_EFETIVADA  ANO_ELEICAO  NR_TURNO SG_UF NM_MUNICIPIO  \
# 182354            2363018         2024         1    PI     TERESINA
# 182355            2398774         2024         1    PI     TERESINA
# 203940            2350866         2024         1    PI     TERESINA
# 203943            2361488         2024         1    PI     TERESINA
# 203944            2345781         2024         1    PI     TERESINA
# ...                   ...          ...       ...   ...          ...
# 498364            2395879         2024         1    PI     TERESINA
# 498365            2396249         2024         1    PI     TERESINA
# 498366            2410806         2024         1    PI     TERESINA
# 498368            2358903         2024         1    PI     TERESINA
# 498369            2344997         2024         1    PI     TERESINA
#
#         CD_CARGO_PERGUNTA                     NM_PARTIDO  QT_COMPARECIMENTO  \
# 182354                 11  Partido Renovação Democrática                324
# 182355                 11  Partido Renovação Democrática                286
# 203940                 11  Partido Renovação Democrática                280
# 203943                 11  Partido Renovação Democrática                233
# 203944                 11  Partido Renovação Democrática                242
# ...                   ...                            ...                ...
# 498364                 11  Partido Renovação Democrática                314
# 498365                 11  Partido Renovação Democrática                288
# 498366                 11  Partido Renovação Democrática                298
# 498368                 11  Partido Renovação Democrática                322
# 498369                 11  Partido Renovação Democrática                182
#
#         QT_ABSTENCOES  NR_VOTAVEL NM_VOTAVEL  QT_VOTOS
# 182354             68          25  DR PESSOA         3
# 182355             72          25  DR PESSOA         6
# 203940             65          25  DR PESSOA         3
# 203943             37          25  DR PESSOA         3
# 203944             51          25  DR PESSOA         7
# ...               ...         ...        ...       ...
# 498364             31          25  DR PESSOA         5
# 498365             67          25  DR PESSOA         8
# 498366             80          25  DR PESSOA         7
# 498368             53          25  DR PESSOA         8
# 498369             44          25  DR PESSOA         6
#
# [1689 rows x 12 columns]

# %%
df_dr_pessoa.QT_VOTOS
# Out:
# 182354    3
# 182355    6
# 203940    3
# 203943    3
# 203944    7
#          ..
# 498364    5
# 498365    8
# 498366    7
# 498368    8
# 498369    6
# Name: QT_VOTOS, Length: 1689, dtype: int64

# %%
df_dr_pessoa.QT_VOTOS.sum()
# Out:
# 10131

# %% [markdown]
# ## Criando gráficos usando o Pandas

# %% [markdown]
# Temperaturas de São Paulo em 2022 (Dados aleatórios)

# %%
import random

# Cria um DataFrame com os dados aleatórios de temperatura
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
temperaturas = [random.randint(12, 35) for i in range(12)]

print(f'Meses: {meses}')
print(f'Temperaturas: {temperaturas}')
# Out:
# Meses: ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
# Temperaturas: [29, 34, 17, 22, 20, 14, 25, 32, 25, 34, 17, 35]

# %% [markdown]
# Agrupa o dados de meses e temperaturas em um dicionario

# %%
dict_meses_temp = {
    'Meses':meses,
    'Temperaturas': temperaturas
}

# %%
dict_meses_temp['Meses']
# Out:
# ['Jan',
#  'Fev',
#  'Mar',
#  'Abr',
#  'Mai',
#  'Jun',
#  'Jul',
#  'Ago',
#  'Set',
#  'Out',
#  'Nov',
#  'Dez']

# %%
dict_meses_temp['Temperaturas']
# Out:
# [29, 34, 17, 22, 20, 14, 25, 32, 25, 34, 17, 35]

# %%
for k, v in dict_meses_temp.items():
  print(k, v)
# Out:
# Meses ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
# Temperaturas [29, 34, 17, 22, 20, 14, 25, 32, 25, 34, 17, 35]

# %% [markdown]
# Converte os dados do dicionário para um Dataframe

# %%
df_meses_temp = pd.DataFrame(dict_meses_temp)
df_meses_temp
# Out:
#    Meses  Temperaturas
# 0    Jan            29
# 1    Fev            34
# 2    Mar            17
# 3    Abr            22
# 4    Mai            20
# 5    Jun            14
# 6    Jul            25
# 7    Ago            32
# 8    Set            25
# 9    Out            34
# 10   Nov            17
# 11   Dez            35

# %% [markdown]
# Coluna Meses

# %%
df_meses_temp['Meses']
# Out:
# 0     Jan
# 1     Fev
# 2     Mar
# 3     Abr
# 4     Mai
# 5     Jun
# 6     Jul
# 7     Ago
# 8     Set
# 9     Out
# 10    Nov
# 11    Dez
# Name: Meses, dtype: object

# %%
type(df_meses_temp['Meses'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Índices da coluna Meses

# %%
df_meses_temp['Meses'].index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %% [markdown]
# Acessando elementos da coluna Meses

# %%
df_meses_temp['Meses'][0]
# Out:
# 'Jan'

# %%
df_meses_temp['Meses'][11]
# Out:
# 'Dez'

# %% [markdown]
# Coluna Temperaturas

# %%
df_meses_temp['Temperaturas']
# Out:
# 0     29
# 1     34
# 2     17
# 3     22
# 4     20
# 5     14
# 6     25
# 7     32
# 8     25
# 9     34
# 10    17
# 11    35
# Name: Temperaturas, dtype: int64

# %%
df_meses_temp['Temperaturas'][0]
# Out:
# 29

# %%
tamanho_series_temperaturas = len(df_meses_temp['Temperaturas'])
tamanho_series_temperaturas
# Out:
# 12

# %%
df_meses_temp['Temperaturas'][tamanho_series_temperaturas-1]
# Out:
# 35

# %% [markdown]
# Colunas do Dataframe df_meses_temp

# %%
df_meses_temp.columns
# Out:
# Index(['Meses', 'Temperaturas'], dtype='object')

# %%
print(df_meses_temp.columns[0])
print(df_meses_temp.columns[1])
# Out:
# Meses
# Temperaturas

# %%
minhas_colunas = ['Meses', 'Temperaturas']

# %%
df_meses_temp[minhas_colunas]
# Out:
#    Meses  Temperaturas
# 0    Jan            29
# 1    Fev            34
# 2    Mar            17
# 3    Abr            22
# 4    Mai            20
# 5    Jun            14
# 6    Jul            25
# 7    Ago            32
# 8    Set            25
# 9    Out            34
# 10   Nov            17
# 11   Dez            35

# %% [markdown]
# Salv o DataFrame em um arquivo texto (.csv)

# %%
# Salva o DataFrame em um arquivo .csv
df_meses_temp.to_csv('temperaturas_sp_2022.csv', index=False)

# %% [markdown]
# Ler o conteúdo do arquivo .csv (usando open(..))

# %%
nome_arquivo = 'temperaturas_sp_2022.csv'
with open(nome_arquivo, mode='r') as f_temp:
  for linha in f_temp:
    print(linha, end='')
# Out:
# Meses,Temperaturas
# Jan,29
# Fev,34
# Mar,17
# Abr,22
# Mai,20
# Jun,14
# Jul,25
# Ago,32
# Set,25
# Out,34
# Nov,17
# Dez,35

# %% [markdown]
# Ler o conteúdo do arquivo .csv (read_csv(...))

# %%
# Lê o arquivo .csv e cria o DataFrame
df = pd.read_csv('temperaturas_sp_2022.csv')

# Mostra o conteudo do dataframe (df)
df
# Out:
#    Meses  Temperaturas
# 0    Jan            29
# 1    Fev            34
# 2    Mar            17
# 3    Abr            22
# 4    Mai            20
# 5    Jun            14
# 6    Jul            25
# 7    Ago            32
# 8    Set            25
# 9    Out            34
# 10   Nov            17
# 11   Dez            35

# %% [markdown]
# Informações do Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Meses         12 non-null     object
#  1   Temperaturas  12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 320.0+ bytes

# %% [markdown]
# Descrição estatística do Dataframe

# %%
df.describe()
# Out:
#        Temperaturas
# count     12.000000
# mean      25.333333
# std        7.438638
# min       14.000000
# 25%       19.250000
# 50%       25.000000
# 75%       32.500000
# max       35.000000

# %%
round(df.describe(), 2)
# Out:
#        Temperaturas
# count         12.00
# mean          25.33
# std            7.44
# min           14.00
# 25%           19.25
# 50%           25.00
# 75%           32.50
# max           35.00

# %% [markdown]
# Extraindo valores do dataframe para gerar um gráfico de série temporal

# %%
# Define os valores dos eixos X e Y
meses = df['Meses']
temperaturas = df['Temperaturas']

print(meses)
print(temperaturas)
# Out:
# 0     Jan
# 1     Fev
# 2     Mar
# 3     Abr
# 4     Mai
# 5     Jun
# 6     Jul
# 7     Ago
# 8     Set
# 9     Out
# 10    Nov
# 11    Dez
# Name: Meses, dtype: object
# 0     29
# 1     34
# 2     17
# 3     22
# 4     20
# 5     14
# 6     25
# 7     32
# 8     25
# 9     34
# 10    17
# 11    35
# Name: Temperaturas, dtype: int64

# %%
meses[0]
# Out:
# 'Jan'

# %%
temperaturas[0]
# Out:
# 29

# %% [markdown]
# Gerando um gráfico de série temporal a partir dos dados extraídos

# %%
# Cria o gráfico de curvas com o Matplotlib
plt.plot(meses, temperaturas)

# Define o título e as legendas dos eixos X e Y
plt.title('Temperaturas em São Paulo - 2022')
plt.xlabel('Meses')
plt.ylabel('Temperatura (ºC)')

# Exibe o gráfico
plt.show()

# %% [markdown]
# Definindo uma classe Grafico genérica

# %%
import numpy as np
import matplotlib.pyplot as plt

class Grafico:
    def __init__(self):
        self.x = None
        self.y = None

    def set_eixo_x(self,x):
      self.x = x

    def set_eixo_y(self,y):
      self.y =y

    def criar_eixo_x(self, inicio, fim, quantidade):
        self.x = np.linspace(inicio, fim, quantidade)

    def calcular_y(self, funcao):
        self.y = funcao(self.x)

    def configura_limites_dos_eixos(self, limite_inferior_x=None, limite_superior_x=None, limite_inferior_y=None, limite_superior_y=None):
        if ((limite_inferior_x is not None) and (limite_superior_x is not None) and (limite_inferior_y is not None) and (limite_superior_y is not None)):
            plt.xlim([limite_inferior_x, limite_superior_x])
            plt.ylim([limite_inferior_y, limite_superior_y])

    def configura_titulo_e_rotulos(self, titulo=None, rotulo_x=None, rotulo_y=None):
        if titulo is not None:
            plt.title(titulo)
        if rotulo_x is not None:
            plt.xlabel(rotulo_x)
        if rotulo_y is not None:
            plt.ylabel(rotulo_y)

    def exibir_gráfico(self):
        plt.plot(self.x, self.y)
        plt.show()

# %%
# Exemplo de uso da classe Gráfico
grafico_temperaturas = Grafico()
grafico_temperaturas.set_eixo_x(x=meses)
grafico_temperaturas.set_eixo_y(y=temperaturas)
grafico_temperaturas.configura_titulo_e_rotulos(titulo='Temperaturas em São Paulo - 2022', rotulo_x='Meses', rotulo_y='Temperatura (ºC)')
grafico_temperaturas.exibir_gráfico()

# %% [markdown]
# # Dataframe
#
# Conjuntos de dados em Pandas são geralmente tabelas multidimensionais, chamadas DataFrames.
#
# A série é como uma coluna, um DataFrame é a tabela inteira.
#
# Um Dataframe é uma estrutura de dados bidimensional, ou seja, os dados são alinhados de forma tabular em linhas e colunas.
#
# Um DataFrame consiste em três componentes principais, os dados, linhas e colunas.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %% [markdown]
# ![dataframe.png](data:image/png;base64,...)

# %% [markdown]
# No mundo real, um DataFrame é criado carregando os conjuntos de dados existente, via banco de dados SQL, **arquivo .CSV**, ou um arquivo Excel. Um DataFrame também pode ser criado a partir de listas, dicionário ou uma de uma lista de dicionários.

# %% [markdown]
# ## Dados 1 - Tabela simplificada de preços de carros

# %%
# Dicionário contendo informações de carros
dicionario_carros_marcas = {
    'carros': ['Corolla', 'Ranger', 'HB-20', 'IX-35'],
    'anos': [2012, 2015, 2018, 2020],
    'valores': [50000, 90000, 60000, 100000],
    'marcas': ['Toyota', 'Ford', 'Hyundai', 'Hyundai']
}

# Cria um dataframe de carros e marcas
df_carros_marcas = pd.DataFrame(dicionario_carros_marcas)
df_carros_marcas
# Out:
#     carros  anos  valores   marcas
# 0  Corolla  2012    50000   Toyota
# 1   Ranger  2015    90000     Ford
# 2    HB-20  2018    60000  Hyundai
# 3    IX-35  2020   100000  Hyundai

# %%
print(f"O dataframe df_carros_marcas tem {df_carros_marcas.shape[0]} linhas e {df_carros_marcas.shape[1]} colunas")
# Out:
# O dataframe df_carros_marcas tem 4 linhas e 4 colunas

# %% [markdown]
# ### Selecionando colunas

# %%
df_carros_marcas
# Out:
#     carros  anos  valores   marcas
# 0  Corolla  2012    50000   Toyota
# 1   Ranger  2015    90000     Ford
# 2    HB-20  2018    60000  Hyundai
# 3    IX-35  2020   100000  Hyundai

# %%
# Seleciona a coluna carros
df_carros_marcas['carros']
# Out:
# 0    Corolla
# 1     Ranger
# 2      HB-20
# 3      IX-35
# Name: carros, dtype: object

# %%
type(df_carros_marcas['carros'])
# Out:
# pandas.core.series.Series

# %%
df_carros_marcas['carros'][2]
# Out:
# 'HB-20'

# %%
# Seleciona os itens da coluna valores
df_carros_marcas['valores']
# Out:
# 0     50000
# 1     90000
# 2     60000
# 3    100000
# Name: valores, dtype: int64

# %%
# Seleciona as colunas carrros e valores
df_carros_marcas[['carros', 'valores']]
# Out:
#     carros  valores
# 0  Corolla    50000
# 1   Ranger    90000
# 2    HB-20    60000
# 3    IX-35   100000

# %%
type(df_carros_marcas[['carros', 'valores']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Convertendo um Dataframe para texto

# %% [markdown]
# Salva um dataframe em arquivo .csv

# %%
df_carros_marcas.to_csv('carros_marcas.csv')

# %%
file_carros_marcas = open('carros_marcas.csv', mode='r')
for linha in file_carros_marcas:
  print(linha, end='')
file_carros_marcas.close()
# Out:
# ,carros,anos,valores,marcas
# 0,Corolla,2012,50000,Toyota
# 1,Ranger,2015,90000,Ford
# 2,HB-20,2018,60000,Hyundai
# 3,IX-35,2020,100000,Hyundai

# %% [markdown]
# ### Análise básica dos dados de um dataframe (1o dataframe)

# %%
# Informacoes sobre as colunas, linhas e tipos
df_carros_marcas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carros   4 non-null      object
#  1   anos     4 non-null      int64
#  2   valores  4 non-null      int64
#  3   marcas   4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
# Tamanho em linhas e colunas (linhas, colunas)
df_carros_marcas.shape
# Out:
# (4, 4)

# %%
df_carros_marcas.describe()
# Out:
#           anos        valores
# count     4.00       4.000000
# mean   2016.25   75000.000000
# std       3.50   23804.761428
# min    2012.00   50000.000000
# 25%    2014.25   57500.000000
# 50%    2016.50   75000.000000
# 75%    2018.50   92500.000000
# max    2020.00  100000.000000

# %%
type(df_carros_marcas.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
# Descricao estatistica das colunas com valores numericos
#df_carros_marcas.describe()
df_carros_marcas.describe().applymap('{:.2f}'.format)
# Out:
#           anos    valores
# count     4.00       4.00
# mean   2016.25   75000.00
# std       3.50   23804.76
# min    2012.00   50000.00
# 25%    2014.25   57500.00
# 50%    2016.50   75000.00
# 75%    2018.50   92500.00
# max    2020.00  100000.00

# %%
# Lista so as duas primeiras linhas
df_carros_marcas.head(2)
# Out:
#     carros  anos  valores  marcas
# 0  Corolla  2012    50000  Toyota
# 1   Ranger  2015    90000    Ford

# %%
# Lista so as duas ultimas linhas
df_carros_marcas.tail(2)
# Out:
#   carros  anos  valores   marcas
# 2  HB-20  2018    60000  Hyundai
# 3  IX-35  2020   100000  Hyundai

# %%
# Extrai os valores unicos de uma coluna
df_carros_marcas['marcas'].unique()
# Out:
# array(['Toyota', 'Ford', 'Hyundai'], dtype=object)

# %%
type(df_carros_marcas['marcas'].unique())
# Out:
# numpy.ndarray

# %%
# Valor medio dos dados de uma coluna
df_carros_marcas['valores'].mean()
# Out:
# 75000.0

# %% [markdown]
# ### Consultas básicas no Dataframe
#
# função Query (consulta)

# %%
df_carros_marcas.query("anos >= 2018")
# Out:
#   carros  anos  valores   marcas
# 2  HB-20  2018    60000  Hyundai
# 3  IX-35  2020   100000  Hyundai

# %%
df_carros_marcas.query("marcas == 'Hyundai'")
# Out:
#   carros  anos  valores   marcas
# 2  HB-20  2018    60000  Hyundai
# 3  IX-35  2020   100000  Hyundai

# %%
df_carros_marcas.query("carros == 'Corolla'")
# Out:
#     carros  anos  valores  marcas
# 0  Corolla  2012    50000  Toyota

# %%
df_carros_marcas.query("valores >= 60000 and marcas=='Ford'")
# Out:
#    carros  anos  valores marcas
# 1  Ranger  2015    90000   Ford

# %% [markdown]
# ## Dados 2 - Tabela Fipe de preços de carros no Brasil

# %%
df_tabela_fipe = pd.read_csv('tabela-fipe-historico-precos.csv')
df_tabela_fipe
# Out:
#         Unnamed: 0 codigoFipe  marca                         modelo  \
# 0                0   038003-2  Acura                 Integra GS 1.8
# 1                1   038001-6  Acura                        NSX 3.0
# 2                2   038003-2  Acura                 Integra GS 1.8
# 3                3   038002-4  Acura                 Legend 3.2/3.5
# 4                4   038002-4  Acura                 Legend 3.2/3.5
# ...            ...        ...    ...                            ...
# 466015      544147   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv
# 466016      544148   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv
# 466017      544149   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv
# 466018      544150   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv
# 466019      544151   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv
#
#         anoModelo  mesReferencia  anoReferencia    valor
# 0            1992             11           2016  13041.0
# 1            1995              3           2013  52339.0
# 2            1992              3           2018  12423.0
# 3            1998              5           2016  31067.0
# 4            1998              2           2019  26381.0
# ...           ...            ...            ...      ...
# 466015       2011              2           2015  24811.0
# 466016       2022              6           2006  31503.0
# 466017       2011              8           2016  23582.0
# 466018       2022              7           2007  31990.0
# 466019       2022              4           2009  34425.0
#
# [466020 rows x 8 columns]

# %%
df_tabela_fipe.columns
# Out:
# Index(['Unnamed: 0', 'codigoFipe', 'marca', 'modelo', 'anoModelo',
#        'mesReferencia', 'anoReferencia', 'valor'],
#       dtype='object')

# %% [markdown]
# Removendo uma coluna de um dataframe
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %%
# Remove a coluna 'Unnamed: 0'
df_tabela_fipe.drop(['Unnamed: 0'], axis=1, inplace=True)
df_tabela_fipe
# Out:
#        codigoFipe  marca                         modelo  anoModelo  \
# 0        038003-2  Acura                 Integra GS 1.8       1992
# 1        038001-6  Acura                        NSX 3.0       1995
# 2        038003-2  Acura                 Integra GS 1.8       1992
# 3        038002-4  Acura                 Legend 3.2/3.5       1998
# 4        038002-4  Acura                 Legend 3.2/3.5       1998
# ...           ...    ...                            ...        ...
# 466015   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv       2011
# 466016   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv       2022
# 466017   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv       2011
# 466018   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv       2022
# 466019   061001-1   Walk  Buggy  Walk Sport 1.6 8V 58cv       2022
#
#         mesReferencia  anoReferencia    valor
# 0                  11           2016  13041.0
# 1                   3           2013  52339.0
# 2                   3           2018  12423.0
# 3                   5           2016  31067.0
# 4                   2           2019  26381.0
# ...               ...            ...      ...
# 466015              2           2015  24811.0
# 466016              6           2006  31503.0
# 466017              8           2016  23582.0
# 466018              7           2007  31990.0
# 466019              4           2009  34425.0
#
# [466020 rows x 7 columns]

# %%
df_tabela_fipe.index
# Out:
# RangeIndex(start=0, stop=466020, step=1)

# %%
len(df_tabela_fipe)
# Out:
# 466020

# %%
df_tabela_fipe.shape
# Out:
# (466020, 7)

# %% [markdown]
# ### Conhecendo os dados (Tabela FIPE) que serão analisados

# %%
df_tabela_fipe.head(5)
# Out:
#   codigoFipe  marca          modelo  anoModelo  mesReferencia  anoReferencia  \
# 0   038003-2  Acura  Integra GS 1.8       1992             11           2016
# 1   038001-6  Acura         NSX 3.0       1995              3           2013
# 2   038003-2  Acura  Integra GS 1.8       1992              3           2018
# 3   038002-4  Acura  Legend 3.2/3.5       1998              5           2016
# 4   038002-4  Acura  Legend 3.2/3.5       1998              2           2019
#
#      valor
# 0  13041.0
# 1  52339.0
# 2  12423.0
# 3  31067.0
# 4  26381.0

# %%
df_tabela_fipe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466020 entries, 0 to 466019
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   codigoFipe     466020 non-null  object
#  1   marca          466020 non-null  object
#  2   modelo         466020 non-null  object
#  3   anoModelo      466020 non-null  int64
#  4   mesReferencia  466020 non-null  int64
#  5   anoReferencia  466020 non-null  int64
#  6   valor          466020 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 24.9+ MB

# %% [markdown]
# Não existem dados nulos no conjunto de dados

# %% [markdown]
# ### 1. Quais são as marcas disponíveis?

# %%
df_tabela_fipe['marca'].unique()
# Out:
# array(['Acura', 'Agrale', 'Alfa Romeo', 'Asia Motors', 'ASTON MARTIN',
#        'Audi', 'Baby', 'BMW', 'BRM', 'Bugre', 'BYD', 'Cadillac',
#        'Caoa Chery', 'CHANA', 'CHANGAN', 'Chrysler', 'Citroën',
#        'Cross Lander', 'Daewoo', 'Daihatsu', 'Dodge', 'EFFA', 'Engesa',
#        'Envemo', 'Ferrari', 'Fiat', 'Fibravan', 'Ford', 'Fyber', 'GEELY',
#        'GM - Chevrolet', 'GREAT WALL', 'Gurgel', 'HAFEI',
#        'HITECH ELECTRIC', 'Honda', 'Hyundai', 'Isuzu', 'JAC', 'Jaguar',
#        'Jeep', 'JINBEI', 'Kia Motors', 'Lada', 'LAMBORGHINI',
#        'Land Rover', 'Lexus', 'LIFAN', 'LOBINI', 'Lotus', 'Mahindra',
#        'Maserati', 'Matra', 'Mazda', 'Mclaren', 'Mercedes-Benz',
#        'Mercury', 'MG', 'MINI', 'Mitsubishi', 'Nissan', 'Peugeot',
#        'Plymouth', 'Pontiac', 'Porsche', 'RAM', 'RELY', 'Renault',
#        'Rolls-Royce', 'Rover', 'Saab', 'Saturn', 'Seat', 'SHINERAY',
#        'smart', 'SSANGYONG', 'Subaru', 'Suzuki', 'Toyota', 'Troller',
#        'Volvo', 'VW - VolksWagen', 'Wake', 'Walk'], dtype=object)

# %%
type(df_tabela_fipe['marca'].unique())
# Out:
# numpy.ndarray

# %%
lista_marcas_disponiveis = df_tabela_fipe['marca'].unique().tolist()
print(f'Existem {len(lista_marcas_disponiveis)} marcas disponíveis: {lista_marcas_disponiveis}')
# Out:
# Existem 84 marcas disponíveis: ['Acura', 'Agrale', 'Alfa Romeo', 'Asia Motors', 'ASTON MARTIN', 'Audi', 'Baby', 'BMW', 'BRM', 'Bugre', 'BYD', 'Cadillac', 'Caoa Chery', 'CHANA', 'CHANGAN', 'Chrysler', 'Citroën', 'Cross Lander', 'Daewoo', 'Daihatsu', 'Dodge', 'EFFA', 'Engesa', 'Envemo', 'Ferrari', 'Fiat', 'Fibravan', 'Ford', 'Fyber', 'GEELY', 'GM - Chevrolet', 'GREAT WALL', 'Gurgel', 'HAFEI', 'HITECH ELECTRIC', 'Honda', 'Hyundai', 'Isuzu', 'JAC', 'Jaguar', 'Jeep', 'JINBEI', 'Kia Motors', 'Lada', 'LAMBORGHINI', 'Land Rover', 'Lexus', 'LIFAN', 'LOBINI', 'Lotus', 'Mahindra', 'Maserati', 'Matra', 'Mazda', 'Mclaren', 'Mercedes-Benz', 'Mercury', 'MG', 'MINI', 'Mitsubishi', 'Nissan', 'Peugeot', 'Plymouth', 'Pontiac', 'Porsche', 'RAM', 'RELY', 'Renault', 'Rolls-Royce', 'Rover', 'Saab', 'Saturn', 'Seat', 'SHINERAY', 'smart', 'SSANGYONG', 'Subaru', 'Suzuki', 'Toyota', 'Troller', 'Volvo', 'VW - VolksWagen', 'Wake', 'Walk']

# %% [markdown]
# ### 2. Quais são os modelos disponíveis?

# %%
df_tabela_fipe['modelo'].unique()
# Out:
# array(['Integra GS 1.8', 'NSX 3.0', 'Legend 3.2/3.5', ...,
#        'Way 1.8 Total Flex 8V Mec.', 'Cross TSI 1.0 TB 12V Flex Mec.',
#        'Buggy  Walk Sport 1.6 8V 58cv'], dtype=object)

# %%
lista_carros_disponiveis = df_tabela_fipe['modelo'].unique().tolist()
print(f'Existem {len(lista_carros_disponiveis)} modelos disponíveis: {lista_carros_disponiveis}')
# Out:
# Existem 5366 modelos disponíveis: ['Integra GS 1.8', 'NSX 3.0', 'Legend 3.2/3.5', 'MARRUÁ AM 200 2.8  CD TDI Diesel', 'MARRUÁ 2.8 12V 132cv TDI Diesel', 'MARRUÁ AM 50 2.8 140cv TDI Diesel', 'MARRUÁ AM 100 2.8  CS TDI Diesel', 'MARRUÁ AM 150 2.8 CD TDI Diesel', 'MARRUÁ AM 200 2.8 CS TDI Diesel', 'MARRUÁ AM 100 2.8 CD TDI Diesel', 'MARRUÁ AM 150 2.8  CS TDI Diesel', '156 TS/Sport/Elegant 2.0 16V', '145 Elegant 2.0 16V', '164 Super V6 24V', '155', '145 Quadrifoglio 2.0', '156 2.5 V6 24V 190cv 4p Aut.', 'Spider 2.0/3.0', '145 Elegant 1.7/1.8 16V', '145 QV', '166 3.0 V6 24V', '155 Super', '164 3.0 V6', '156 Sport Wagon 2.0 16V', '156 Sport Wagon 2.5 V6 24V 4p Aut.', '2300 TI/TI-4', '147 2.0 16V 148cv 4p Semi-Aut.', 'Towner SDX / DLX/ STD', 'Towner Multiuso 5p', 'Towner Pick-Up', 'Towner Glass Van', 'Towner Coach Full', 'Towner Furgão', 'Towner Truck', 'Towner Panel Van', 'Towner Super Luxo', 'Towner Luxo', 'Vanquish V12 6.0 565cv', 'DB9 Coupe 6.0 V12 510cv', 'Vantage Coupe 4.7 V8 425cv', 'Rapide 6.0 V12 477cv', 'Rapide S 6.0 V12 550cv', 'Virage Coupe 6.0 V12 490cv', 'Vantage S Coupe 4.7 V8 430cv', 'DB9 Volante 6.0 V12 470cv', 'Vantage 6.0 V12 510cv', 'Vantage Roadster 4.7 V8 420cv', 'Vantage S 6.0 V12 565cv', 'A4 1.8 Avant Turbo Tip./ Multitronic', 'A6 2.8 Avant 30V Tiptronic', 'Q5 2.0 16V TFSI Quattro S Tronic', 'A4 2.0 16V TFSI 183/180cv Multitronic', 'A4 2.0 Avant TFSI 200/214cv Multitron.', 'TTRS Roadster 2.5 TB FSI Quat. S Tronic', 'A3 Sed. Ambition 2.0 TSFI 220cv S-tronic', 'A4 1.8 Turbo', 'A6 2.8 Avant V6 30V Quattro Mec.', 'A4 2.0 Avant Ambie. 2.0 16V TFSi S tron.', 'A6 2.4 Avant 30V Mec.', 'A3 1.6 5p Aut.', 'A4 3.2 FSI 24V 269cv Quattro Tiptronic', 'A6 3.0 Avant V6 30V 218cv Multitronic 5p', 'A4 2.8 30V  Tiptronic/ Aut.', 'A5 Sportback 2.0 16V TFSI 180cv Multi.', 'A4 3.0 30V 218cv Quattro Tiptron./Aut 4p', 'A1 1.4 TFSI 122cv S-tronic 3p', 'A4 2.8 Avant V6 30V Quattro Mec.', '80 2.0 Avant', 'A5 Ambit. Sport. 2.0 TFSI S tronic', 'A6 2.7 Quattro Tiptronic', '100 S-4 2.2 Avant Turbo', 'A4 2.8 Avant V6 30V Tiptronic', 'Q7 4.2 V8 40V 350cv Quattro Tiptronic', 'Q8 Perf.Bl. 3.0 TFSI Coupe Quat. S-tron.', 'A1 Sportback 1.4 TFSI 5p S-tronic', 'A3 Sedan 1.4/ Attra. 16V TB FSI S-tronic', 'A4 3.2 FSI Avant 24V 255cv Multitronic', 'A6 2.8 Avant', 'A3 1.8 Turbo 180cv 3p Aut./ Tip.', 'A4 1.8 Avant Turbo Mec.', 'A3 1.6 5p', 'A4 Ambiente 2.0 TFSI 190cv S tronic', 'S3 Sportback 2.0 TFSI Quattro S Tronic', 'A4 2.4 Avant V6 30V Quattro Mec.', 'A4 2.8 V6 30V  Quattro Tiptronic', 'Q7 3.6 V6 284cv Quattro Tiptronic', 'Q5 Ambiente 2.0 TFSI Quattro S tronic', 'A3 Sportback 1.8 16V TFSI S-tronic 5p', 'A6 2.7 30V Avant Tiptronic', 'RS6 4.0 Avant TFSI BI-TB Quattro Tip. 5p', '100 2.8 V6', 'Allroad 2.7 30V Quattro Turbo Tiptronic', 'A1 Sport 1.4 TFSI 185cv 3p S-tronic', 'A3 1.6 8V 102cv 3p', 'A4 2.8 30V Mec.', 'A4 2.0 16V TFSI Quattro Stronic', 'A1 Sport. S Edition 1.4 TFSI 5p S-tronic', '80 2.6/2.8 Avant', 'Q3 2.0 TFSI Quat. 170/180cv S-tronic 5p', 'S8 4.2 Quattro Mec.', 'Q5 2.0 16V TFSI 225cv Quattro Tiptronic', 'A4 2.8 Avant V6 30V Mec.', 'A4 2.4 30V Avant Tip./Multitronic', '80 2.8 Cabriolet', 'S6 Plus 4.2 Avant V8 32V', 'A4 3.0 30V 218cv Multitronic 4p', 'A3 Sport 2.0 16V TFSI S- tronic', 'TTS 2.0 TFSI QUATTRO S Tronic', 'A6 4.2 Quattro Tiptronic', 'Q5 Prestige Plus 2.0 TFSI Quat. S tronic', 'A5 3.2 FSI V6 24V 269cv Quattro Tiptroni', 'A3 Sed.1.8/1.8 Ambit.16V TB FSI S-tronic', 'S4 4.2 Avant V8 40V 344cv Quattro Tipt.', 'A6 2.4 Avant V6 30V Quattro Tiptronic', 'S5 Cabriolet 3.0 TFSI Quattro Stronic', 'RS6 5.0 FSI V10 Bi-TB Quattro Tip.', 'A3 Sedan Performance 2.0 TFSI S-tronic', 'R8 5.2 V10 Quattro R-tronic/S-tronic', 'A7 Sportback 2.0 TFSI S Tronic', 'A4 2.0 20V 130cv Multitronic 4p', '80 2.0', 'A6 4.2 Avant Quattro Tiptronic', 'A6 2.4 30V Mec', 'TT 2.0 16v TFSI S-Tronic', 'RS7 Sportback 4.0 TFSI Quattro Tiptronic', 'TT 1.8 TB Quattro 225cv', 'A5 Sportb. 2.0 16V TFSI Quat. S-tronic', 'A6 2.8 30V Mec.', 'S Q5 3.0 V6 TFSI 354cv Quattro Tiptronic',  ...

# %% [markdown]
# ### 3. Qual o ano do carro mais antigo e do carro mais novo?

# %%
print(f"Menor ano de fabricação: {df_tabela_fipe['anoModelo'].min()}, maior ano de fabricação: {df_tabela_fipe['anoModelo'].max()}")
# Out:
# Menor ano de fabricação: 1985, maior ano de fabricação: 2023

# %% [markdown]
# ### 4. Quais são os modelos de carros mais antigos?

# %%
menor_ano = df_tabela_fipe['anoModelo'].min()

# %%
df_carro_mais_antigo = df_tabela_fipe.query(f"anoModelo == {menor_ano}")
df_carro_mais_antigo
# Out:
#       codigoFipe marca modelo  anoModelo  mesReferencia  anoReferencia   valor
# 92001   001105-3  Fiat   Oggi       1985              5           2022  3289.0
# 92182   001105-3  Fiat   Oggi       1985              7           2022  3305.0
# 92270   001105-3  Fiat   Oggi       1985              8           2022  3285.0
# 93115   001105-3  Fiat   Oggi       1985              6           2022  3315.0

# %%
df_carro_mais_antigo['modelo'].unique()
# Out:
# array(['Oggi'], dtype=object)

# %%
df_carro_mais_antigo['modelo'].unique()[0]
# Out:
# 'Oggi'

# %% [markdown]
# ### 5. Quais são os modelos de carros mais novos?

# %%
maior_ano = df_tabela_fipe['anoModelo'].max()

# %%
df_carro_mais_novo = df_tabela_fipe.query(f"anoModelo == {maior_ano}")
df_carro_mais_novo
# Out:
#       codigoFipe marca                  modelo  anoModelo  mesReferencia  \
# 43159   039001-1   BRM  Buggy/M-8/M-8 Long 1.6       2023              8
#
#        anoReferencia    valor
# 43159           2022  83377.0

# %%
indice_carro_mais_novo = df_carro_mais_novo.index
type(indice_carro_mais_novo)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
indice_carro_mais_novo[0]
# Out:
# 43159

# %%
df_carro_mais_novo['modelo'][indice_carro_mais_novo[0]]
# Out:
# 'Buggy/M-8/M-8 Long 1.6'

# %% [markdown]
# ### 6. Qual a média dos valores dos carros da Toyota de 2022 (anoModelo)

# %%
df_tabela_fipe.query("anoModelo == 2022 and marca=='Toyota'")
# Out:
#        codigoFipe   marca                                    modelo  \
# 392382   002060-5  Toyota        Corolla SE-G 1.8/1.8 Flex 16V Aut.
# 392384   002107-5  Toyota   Hilux SW4 SR 4x2 2.7/ 2.7 Flex 16V Aut.
# 392385   002151-2  Toyota       ETIOS XS Sedan 1.5 Flex 16V 4p Aut.
# 392390   002190-3  Toyota     YARIS XS Connect 1.5 Flex 16V 5p Aut.
# 392391   002027-3  Toyota         Corolla XLi 1.8/1.8 Flex 16V Mec.
# ...           ...     ...                                       ...
# 412989   002090-7  Toyota       Hilux CD SR D4-D 4x4 3.0  TDI Dies.
# 412990   002132-6  Toyota             ETIOS XS 1.5 Flex 16V 5p Mec.
# 412991   002140-7  Toyota                 RAV4 2.0 TOP 4x2 16V Aut.
# 412993   002085-0  Toyota  Hilux CS D4-D 4x2 2.5 16V 102cv TB Dies.
# 412995   002076-1  Toyota        Hilux CD SR 4x4 3.0 8V 90cv Diesel
#
#         anoModelo  mesReferencia  anoReferencia     valor
# 392382       2022              5           2002   49944.0
# 392384       2022              9           2021  232005.0
# 392385       2022              1           2017   55845.0
# 392390       2022              1           2021   85161.0
# 392391       2022              8           2002   32536.0
# ...           ...            ...            ...       ...
# 412989       2022              6           2009   97289.0
# 412990       2022             10           2015   44201.0
# 412991       2022              9           2015  130314.0
# 412993       2022              2           2010   73050.0
# 412995       2022              1           2002   55714.0
#
# [7523 rows x 7 columns]

# %%
df_carros_toyota_2022 = df_tabela_fipe.query("anoModelo == 2022 and marca=='Toyota'")
valor_medio_carros_toyota_2022 = round(df_carros_toyota_2022['valor'].mean(), 2)
print(f'O valor médio dos {len(df_carros_toyota_2022)} carros da Toyota com ano 2022 é: {valor_medio_carros_toyota_2022}')
# Out:
# O valor médio dos 7523 carros da Toyota com ano 2022 é: 92886.92

# %% [markdown]
# Quais são estes carros?

# %%
df_carros_toyota_2022['modelo'].unique()
# Out:
# array(['Corolla SE-G 1.8/1.8 Flex 16V Aut.',
#        'Hilux SW4 SR 4x2 2.7/ 2.7 Flex 16V Aut.',
#        'ETIOS XS Sedan 1.5 Flex 16V 4p Aut.',
#        'YARIS XS Connect 1.5 Flex 16V 5p Aut.',
#        'Corolla XLi 1.8/1.8 Flex 16V Mec.',
#        'Corolla Fielder SW 1.8/1.8 XEi Flex Aut.',
#        'Camry XLE 3.5 24V Aut.', 'ETIOS XLS 1.5 Flex 16V 5p Mec.',
#        'Corona Mec.', 'Corolla GLi 1.8 Flex 16V  Aut.',
#        'ETIOS XS Sedan1.5 Flex 16V 4p Mec.',
#        'ETIOS X 1.3 Flex 16V 5p Aut.',
#        'YARIS XL Plus Con. 1.5 Flex 16V 5p Aut.',
#        'ETIOS X Sedan 1.5 Flex 16V 4p Mec.',
#        'YARIS XS Connect Sedan 1.5 Flex 16V Aut.',
#        'Corolla Fielder SW 1.8/1.8 XEi Flex Mec',
#        'ETIOS PLATINUM Sed. 1.5 Flex 16V 4p Mec.',
#        'YARIS XL Plus Con. Sed. 1.5 Flex 16V Aut',
#        'Hilux CD SR 4x4 3.0 8V 116cv TB Diesel',
#        'Corolla ALTIS 2.0 Flex 16V Aut.', 'Corolla XEi 2.0 Flex 16V Aut.',
#        'Hilux SW4 2.7 16V', 'YARIS XLS Sedan 1.5 Flex 16V 4p Aut.',
#        'ETIOS X Plus 1.5 Flex 16V 5p Mec.',
#        'ETIOS PLATINUM 1.5 Flex 16V 4p Aut.',
#        'ETIOS X 1.3 Flex 16V 5p Mec.',
#        'Hilux CS DX 4x2 3.0 8V 90cv Diesel',
#        'YARIS XL 1.3 Flex 16V 5p Mec.',
#        'Hilux CD SRV D4-D 4x4 3.0  TDI Dies',
#        'ETIOS READY! 1.5 Flex 16V 5p Aut.',
#        'Hilux CD DX 4x4 3.0 8V 90cv Diesel',
#        'Hilux CD SRV 4x2 3.0 8V 90cv Diesel',
#        'PRIUS Hybrid 1.8 16V 5p Aut.', 'RAV4 2.4 4x4 16V 170cv Aut.',
#        'Hilux SW4 SRV D4-D 4x4 3.0 TDI Dies. Aut',
#        'RAV4 2.0 4x4 16V Mec.', 'YARIS XL Plus Tech 1.3 Flex 16V Aut.',
#        'Hilux CD SR 4x4 3.0 8V 90cv Diesel', 'RAV4 2.5 4x4 16V Aut.',
#        'Hilux SW4 3.4 V6', 'RAV4 2.0 4x4 16V Aut.',
#        'Hilux Chassi D4-D 4x4 2.5 102cv TB Dies.',
#        'Corolla XEi 1.8/1.8 Flex 16V Mec.',
#        'YARIS XL Sedan 1.5 Flex 16V 4p Aut.', 'Camry XLE 3.0 24V 186cv',
#        'Corolla GLi 1.8 Flex 16V Mec.', 'Corolla XRS 2.0 Flex 16V Aut.',
#        'ETIOS X Plus Sedan 1.5 Flex 16V 4p Aut.',
#        'YARIS XS Sedan 1.5 Flex 16V 4p Aut.',
#        'Hilux CD SR D4-D 4x2 3.0 163cv TDI Dies.',
#        'Hilux SW4 SRV 4x2 2.7 Flex 16V Aut.',
#        'ETIOS XS 1.5 Flex 16V 5p Mec.',
#        'Corolla XEi 1.8/1.8 Flex 16V Aut.',
#        'ETIOS X Plus 1.5 Flex 16V 5p Aut.',
#        'Hilux CD D4-D 4x4 2.5 16V 102cv TB Dies.',
#        'Hilux CS DX 4x4 3.0 8V 90cv Diesel',
#        'ETIOS XS 1.5 Flex 16V 5p Aut.',
#        'YARIS XLS Connect 1.5 Flex 16V 5p Aut.',
#        'Hilux SW4 SRV D4-D 4x4 3.0 TDI Dies. Mec',
#        'Corolla S 1.8 16V 136cv Mec',
#        'Corolla ALTIS/A.Premiu. 2.0 Flex 16V Aut',
#        'ETIOS CROSS 1.5 Flex 16V 5p Aut.', 'Hilux SW4 4x4 3.0 24V V6',
#        'Corolla GLi Upper Black P. 1.8 Flex Aut.',
#        'Hilux SW4 SRV 4x4 4.0 V6 24V Aut.',
#        'Corolla XLi 1.8/1.8 Flex 16V Aut.', 'Corolla SE-G 1.8 16V Mec.',
#        'Corolla XLi 1.6 16V 110cv Aut.',
#        'Corolla Cross XR 2.0 16V Flex Aut.',
#        'Corolla Fielder SW S 1.8 16V 136cv Mec',
#        'RAV4 2.5 SX Connect 4x4 Hybrid Aut.',
#        'Corolla Fielder SW SE-G 1.8 Flex 16V Aut',
#        'Hilux CD SRV 4x4 2.7 Flex 16V Aut.',
#        'Hilux CD SR D4-D 4x4 3.0  TDI Dies.', 'Camry LE',
#        'ETIOS PLATINUM Sed. 1.5 Flex 16V 4p Aut.',
#        'Hilux CD SR 4x2 2.7 16V/2.7 Flex Aut.',
#        'RAV4 2.5 S Connect 4x4 Hybrid Aut.',
#        'Hilux CD SRV 4x2 2.7 Flex 16V Aut.',
#        'Corolla Fielder SW S  1.8 16V 136cv Aut',
#        'Hilux CS SRV 4x2 2.7 16V 142cv',
#        'Corolla GLi Upper 1.8 Flex 16V Aut.',
#        'YARIS XL 1.3 Flex 16V 5p Aut.',
#        'Hilux CD SR 4x2 2.7 16V/2.7 Flex Mec.',
#        'Hilux CD DX 4x2 3.0 8V 90cv Diesel',
#        'Hilux SW4 SRX 4x4 4.0 V6 24V Aut.',
#        'Land Cruiser Prado 3.0 4x4 TB Diesel Aut',
#        'Hilux CD D4-D 4x2 2.5 16V 102cv TB Dies.',
#        'YARIS XL Plus T. Sed. 1.5 Flex 16V Aut.', 'RAV4 2.0 4x2 16V Aut.',
#        'ETIOS CROSS 1.5 Flex 16V 5p Mec.',
#        'Hilux CS DX 4x2 2.7 16V 142cv',
#        'Hilux CS D4-D 4x4 2.5 16V 102cv TB Dies.',
#        'YARIS XL Live Sedan 1.5 Flex 16V 4p Aut.',
#        'ETIOS X Sedan 1.5 Flex 16V 4p Aut.',
#        'Corolla Cross XRV 1.8 16V Aut.(Híbrido)',
#        'Hilux CS D4-D 4x2 2.5 16V 102cv TB Dies.',
#        'Corolla XLi 1.6 16V 110cv Mec.',
#        'Hilux CD SRV 4x4 3.0 8V 116cv TB Diesel',
#        'Hilux SW4 SR 4x2 2.7/2.7 Flex 16V Mec.',
#        'ETIOS XLS Sedan 1.5 Flex 16V 4p Mec.',
#        'YARIS XS 1.5 Flex 16V 5p Aut.',
#        'Hilux CD SRV D4-D 4x4 3.0 TDI Diesel Aut',
#        'Corolla Cross XRE 2.0 16V Flex Aut.',
#        'ETIOS XLS Sedan 1.5 Flex 16V 4p Aut.', 'Corona GLi Mec',
#        'RAV4 2.0 TOP 4x2 16V Aut.', 'ETIOS XLS 1.5 Flex 5p Aut.',
#        'Corolla Dynamic 2.0 Flex 16V Aut.',
#        'Hilux CD 4x4 2.7 16V Flex Mec.', 'RAV4 2.5 SX 4x4 Hybrid Aut.',
#        'ETIOS PLATINUM 1.5 Flex 16V 5p Mec.',
#        'YARIS XLS 1.5 Flex 16V 5p Aut.', 'Corolla S 1.8 16V 136cv Aut',
#        'RAV4 2.4 4x2 16V 170cv Aut.',
#        'YARIS XL Live Sedan 1.5 Flex 16V 4p Mec.',
#        'YARIS XLS Connect Sed. 1.5 Flex 16V Aut.',
#        'Hilux CD SRV D4-D 4x2 3.0 163cv TDI Dies',
#        'ETIOS XS  1.3 Flex 16V 5p Mec.', 'Corolla GLi 2.0 16V Flex Aut.',
#        'Corolla GR-Sport 2.0 Flex 16V Aut.',
#        'Hilux CD DX 4x2 2.7 16V 142cv',
#        'YARIS XL Sedan 1.5 Flex 16V 4p Mec.',
#        'Land Cruiser Prado 3.0 4x4 TB Diesel Mec',
#        'Corolla Cross SE 1.8 16V Aut. (Híbrido)',
#        'RAV4 2.5 S 4x4 Hybrid Aut.', 'YARIS XL Live 1.3 Flex 16V 5p Aut.',
#        'Hilux CD SRV 4x2 2.7 16V 142cv', 'YARIS S 1.5 Flex 16V 5p Aut.',
#        'ETIOS 1.3 Flex 16V 5p Mec.', 'YARIS XL Live 1.3 Flex 16V 5p Mec.',
#        'Corolla Altis Prem. Hybrid 1.8 Flex Aut',
#        'Corolla Altis Hybrid 1.8 16V Flex Aut.',
#        'Hilux CD SR D4-D 4x4 3.0 TDI Dies Aut.',
#        'YARIS X-WAY Connect 1.5 Flex 16V 5p Aut.',
#        'ETIOS X Plus Sedan 1.5 Flex 16V 4p Mec.',
#        'YARIS X-WAY 1.5 Flex 16V 5p Aut.',
#        'Hilux CD GR-S 4x4 4.0 V6 234cv Aut.',
#        'RAV4 2.0 HIGH 4x2 16V Aut.',
#        'Corolla Cross SE 1.8 16V Aut. (Hybrid)',
#        'YARIS XL 1.5 Flex 16V 5p Aut.',
#        'Corolla Cross XRX 1.8 16V Aut.(Híbrido)',
#        'Camry XLE Hybrid 2.5 16V Aut. ',
#        'Corolla Cross XRV 1.8 16V Aut.(Hybrid)',
#        'Corolla Cross GR-S 2.0 16V Flex Aut.',
#        'Corolla Cross XRX 1.8 16V Aut.(Hybrid)',
#        'Corolla Altis Prem. Hybrid 1.8 Aut',
#        'Corolla Altis Hybrid 1.8 16V Aut.', 'Corona Aut.'], dtype=object)

# %%
lista_carros_toyota_2022 = df_carros_toyota_2022['modelo'].unique().tolist()
print(f"Existem {len(lista_carros_toyota_2022)} modelos da Toyota de fabricação 2022")
# Out:
# Existem 149 modelos da Toyota de fabricação 2022

# %% [markdown]
# Quais são os registros de carros Corolla?

# %%
df_carros_toyota_2022['modelo']
# Out:
# 392382          Corolla SE-G 1.8/1.8 Flex 16V Aut.
# 392384     Hilux SW4 SR 4x2 2.7/ 2.7 Flex 16V Aut.
# 392385         ETIOS XS Sedan 1.5 Flex 16V 4p Aut.
# 392390       YARIS XS Connect 1.5 Flex 16V 5p Aut.
# 392391           Corolla XLi 1.8/1.8 Flex 16V Mec.
#                             ...
# 412989         Hilux CD SR D4-D 4x4 3.0  TDI Dies.
# 412990               ETIOS XS 1.5 Flex 16V 5p Mec.
# 412991                   RAV4 2.0 TOP 4x2 16V Aut.
# 412993    Hilux CS D4-D 4x2 2.5 16V 102cv TB Dies.
# 412995          Hilux CD SR 4x4 3.0 8V 90cv Diesel
# Name: modelo, Length: 7523, dtype: object

# %%
carros_corolla_2022 = df_carros_toyota_2022['modelo'].str.contains("Corolla")
carros_corolla_2022
# Out:
# 392382     True
# 392384    False
# 392385    False
# 392390    False
# 392391     True
#           ...
# 412989    False
# 412990    False
# 412991    False
# 412993    False
# 412995    False
# Name: modelo, Length: 7523, dtype: bool

# %%
type(carros_corolla_2022)
# Out:
# pandas.core.series.Series

# %%
df_corollas_2022 = df_carros_toyota_2022[carros_corolla_2022]
df_corollas_2022
# Out:
#        codigoFipe   marca                                    modelo  \
# 392382   002060-5  Toyota        Corolla SE-G 1.8/1.8 Flex 16V Aut.
# 392391   002027-3  Toyota         Corolla XLi 1.8/1.8 Flex 16V Mec.
# 392392   002084-2  Toyota  Corolla Fielder SW 1.8/1.8 XEi Flex Aut.
# 392402   002060-5  Toyota        Corolla SE-G 1.8/1.8 Flex 16V Aut.
# 392417   002109-1  Toyota            Corolla GLi 1.8 Flex 16V  Aut.
# ...           ...     ...                                       ...
# 412971   002028-1  Toyota         Corolla XEi 1.8/1.8 Flex 16V Mec.
# 412975   002112-1  Toyota           Corolla ALTIS 2.0 Flex 16V Aut.
# 412980   002028-1  Toyota         Corolla XEi 1.8/1.8 Flex 16V Mec.
# 412983   002061-3  Toyota         Corolla XEi 1.8/1.8 Flex 16V Aut.
# 412984   002062-1  Toyota         Corolla XLi 1.8/1.8 Flex 16V Aut.
#
#         anoModelo  mesReferencia  anoReferencia     valor
# 392382       2022              5           2002   49944.0
# 392391       2022              8           2002   32536.0
# 392392       2022              8           2004   64655.0
# 392402       2022              2           2010   82291.0
# 392417       2022              7           2010   68000.0
# ...           ...            ...            ...       ...
# 412971       2022              7           2002   36948.0
# 412975       2022              1           2021  139197.0
# 412980       2022             11           2009   65915.0
# 412983       2022             11           2006   62062.0
# 412984       2022              2           2002   36903.0
#
# [2013 rows x 7 columns]

# %%
print(f"Existem {len(df_carros_toyota_2022[carros_corolla_2022])} registros de Corolas 2022")
# Out:
# Existem 2013 registros de Corolas 2022

# %%
df_corollas_2022 = df_corollas_2022.sort_values(by=['valor'])
df_corollas_2022
# Out:
#        codigoFipe   marca                                   modelo  anoModelo  \
# 406140   002027-3  Toyota        Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 405652   002027-3  Toyota        Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 392620   002027-3  Toyota        Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 399030   002027-3  Toyota        Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 403916   002027-3  Toyota        Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# ...           ...     ...                                      ...        ...
# 412748   002202-0  Toyota  Corolla Cross SE 1.8 16V Aut. (Híbrido)       2022
# 406606   002202-0  Toyota  Corolla Cross SE 1.8 16V Aut. (Híbrido)       2022
# 397726   002202-0  Toyota  Corolla Cross SE 1.8 16V Aut. (Híbrido)       2022
# 395247   002202-0  Toyota  Corolla Cross SE 1.8 16V Aut. (Híbrido)       2022
# 406749   002202-0  Toyota  Corolla Cross SE 1.8 16V Aut. (Híbrido)       2022
#
#         mesReferencia  anoReferencia     valor
# 406140              2           2002   31223.0
# 405652              1           2002   31329.0
# 392620              9           2002   31342.0
# 399030              3           2002   31670.0
# 403916              7           2002   32287.0
# ...               ...            ...       ...
# 412748              3           2022  209844.0
# 406606              4           2022  211522.0
# 397726              5           2022  213214.0
# 395247              7           2022  214274.0
# 406749              6           2022  214919.0
#
# [2013 rows x 7 columns]

# %% [markdown]
# Qual o preço médio de um Corola 2022?

# %%
df_corollas_2022['valor'].mean()
# Out:
# 80312.00645802285

# %%
print(f"preço médio de um Corolla 2022: {round(df_corollas_2022['valor'].mean(), 2)}")
# Out:
# preço médio de um Corolla 2022: 80312.01

# %% [markdown]
# Qual a distribuição de frequência dos preços dos Corollas 2022?

# %%
df_corollas_2022['valor'].hist(bins=4)
# Out:
# <Axes: >

# %%
df_corollas_2022.query('valor < 75000')
# Out:
#        codigoFipe   marca                              modelo  anoModelo  \
# 406140   002027-3  Toyota   Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 405652   002027-3  Toyota   Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 392620   002027-3  Toyota   Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 399030   002027-3  Toyota   Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# 403916   002027-3  Toyota   Corolla XLi 1.8/1.8 Flex 16V Mec.       2022
# ...           ...     ...                                 ...        ...
# 398929   002111-3  Toyota       Corolla XEi 2.0 Flex 16V Aut.       2022
# 400708   002111-3  Toyota       Corolla XEi 2.0 Flex 16V Aut.       2022
# 392592   002061-3  Toyota   Corolla XEi 1.8/1.8 Flex 16V Aut.       2022
# 401415   002061-3  Toyota   Corolla XEi 1.8/1.8 Flex 16V Aut.       2022
# 407238   002060-5  Toyota  Corolla SE-G 1.8/1.8 Flex 16V Aut.       2022
#
#         mesReferencia  anoReferencia    valor
# 406140              2           2002  31223.0
# 405652              1           2002  31329.0
# 392620              9           2002  31342.0
# 399030              3           2002  31670.0
# 403916              7           2002  32287.0
# ...               ...            ...      ...
# 398929              5           2010  74874.0
# 400708              4           2010  74874.0
# 392592             11           2008  74880.0
# 401415             10           2008  74895.0
# 407238              5           2006  74980.0
#
# [1304 rows x 7 columns]

# %%
df_corollas_2022.query('valor >= 75000 and valor < 125000')
# Out:
#        codigoFipe   marca                                   modelo  anoModelo  \
# 410869   002111-3  Toyota            Corolla XEi 2.0 Flex 16V Aut.       2022
# 410094   002060-5  Toyota       Corolla SE-G 1.8/1.8 Flex 16V Aut.       2022
# 393304   002060-5  Toyota       Corolla SE-G 1.8/1.8 Flex 16V Aut.       2022
# 411121   002102-4  Toyota  Corolla Fielder SW S  1.8 16V 136cv Aut       2022
# 395159   002060-5  Toyota       Corolla SE-G 1.8/1.8 Flex 16V Aut.       2022
# ...           ...     ...                                      ...        ...
# 404063   002112-1  Toyota          Corolla ALTIS 2.0 Flex 16V Aut.       2022
# 404564   002181-4  Toyota            Corolla GLi 2.0 16V Flex Aut.       2022
# 409239   002111-3  Toyota            Corolla XEi 2.0 Flex 16V Aut.       2022
# 412382   002111-3  Toyota            Corolla XEi 2.0 Flex 16V Aut.       2022
# 410803   002112-1  Toyota          Corolla ALTIS 2.0 Flex 16V Aut.       2022
#
#         mesReferencia  anoReferencia     valor
# 410869             10           2010   75000.0
# 410094              5           2011   75025.0
# 393304              6           2006   75043.0
# 411121              3           2007   75057.0
# 395159             11           2005   75061.0
# ...               ...            ...       ...
# 404063             10           2019  122668.0
# 404564              3           2021  123298.0
# 409239             11           2020  123427.0
# 412382              1           2021  123795.0
# 410803             11           2019  124841.0
#
# [466 rows x 7 columns]
