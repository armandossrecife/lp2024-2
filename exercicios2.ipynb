# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/lp2024-2/blob/main/exercicios2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Listas

# %% [markdown]
# ## Exercício 1
#
# Dadas seguintes informações:
#
# aluno1 = ['Maria', 'F','Ciência da Computação','Laboratório de Programação', 9]
#
# aluno2 = ['Carla', 'F','Ciência da Computação', 'Engenharia de Software I', 8.5]
#
# aluno3 = ['Ana', 'F','Ciência da Computação','Compiladores', 7.7]
#
# aluno4 = ['Francisco', 'M', 'Ciência da Computação', 'Probalidade e Estatística', 10]
#
# aluno5 = ['Pedro', 'M', 'Matemática', 'Algebra I', 7]
#
# aluno6 = ['Joana', 'F','Matemática', 'Algebra I', 7]
#
# aluno7 = ['Roberto','M','Física', 'Física I', 9]
#
# aluno8 = ['Daniele', 'F', 'Física', 'Física II', 5.8]

# %%
# Crie uma lista contendo os 8 alunos
lista_alunos = []

# Crie uma listra contendo apenas os alunos do Curso de Ciência da Computação
lista_alunos_computacao = []

# Crie uma lista contendo apenas os alunos de matemática
lista_alunos_matematica = []

# Crie uma lista contendo apenas os alunos de física
lista_alunos_fisica = []

# Crie uma lista contendo apenas os alunos homens
lista_alunos_homens = []

# crie uma lista contendo apenas as alunas mulheres
lista_alunas_mulheres = []

# crie uma lsita contendo apenas alunos com notas superiores a 7
lista_alunos_maior_7 = []

# Crie uma lista na ordem alfabética crescente contendo os 8 alunos
lista_alunos_crescente = []

# Crie uma lista na ordem alfabética decrescente contendo os 8 alunos
lista_alunos_decrescente = []

# %% [markdown]
# ## Exercício 2
#
# Dadas as seguintes matrizes:
#
# \begin{equation}
# A = \begin{pmatrix} 1 & 2\\ 3 & 4 \end{pmatrix}
# \end{equation}
#
# \begin{equation}
# B = \begin{pmatrix} 5 & 6\\ 7 & 8 \end{pmatrix}
# \end{equation}
#
# Crie as matrizes:
#
# C = A + B
#
# D = A - B

# %% [markdown]
# # Tuplas

# %% [markdown]
# ## Exercício 1
#
# Um terreno retangular pode ser representado por uma tupla (base, altura). Leia as informações de 3 terrenos retangulares e mostre os seguintes relatórios:
# - Liste todos os terrenos cadastrados
# - Informe qual a maior área dos terrenos?
# - Informe qual a menor área dos terrenos?

# %% [markdown]
# ## Exercício 2
#
# Leia dois pontos no plano cartesiano 2d e calcule a distância euclidiana entre eles.

# %% [markdown]
# ![euclidean-distance-formula-derivation-1624039182.png](data:image/png;base64,...)

# %% [markdown]
# # Set

# %% [markdown]
# ## Exercício 1
#
# Dados os conjuntos s1 = {1, 2, 3, 4, 5} e s2 = {2, 4, 6, 8}
# - Qual é o resultado da união dos dois conjuntos?
# - Qual é o resultado da interseção entre os dois conjuntos?
# - Qual é o resultado de s1-s2?
# - Qual é o resultado de s2-s1?
